# %%
import requests as r
import json
import re
from bs4 import BeautifulSoup

# %%
url = 'http://buy.sinyi.com.tw/house/42070W.html'
cookies = {'__uid':'wKgIZFfOTpQOZ1ASBKIKAg==', '_gat_UA-12807964-17':'1', '__uwait':'0', '_ga':'GA1.3.892072981.1473138334', '__BWfp':'c1473138339515x5067b476a', '_gat':'1', '_ga':'GA1.4.892072981.1473138334'}
headers = {'User-Agent':'Chrome/52.0.2743.116'}
res = r.get(url, headers = headers, cookies = cookies)
# type(res) : requests.models.Response
print res.text
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <script>(function(w,d,s,l,i){w[l]={'start':new Date().getTime(),id:i};
# var f=d.getElementsByTagName(s)[0],j=d.createElement(s);j.async=true;
# j.src='//img.sinyi.com/j/'+l+'.js';f.parentNode.insertBefore(j,f);
# })(window,document,'script','sy','57d3b79b8c73ec45432eaf27');</script>
#
# <script type="text/javascript">
# 	var krpano_obj_code = '42070W';
# 	var new_image_dir = "http://img.sinyi.com/i/new_item_page";
# </script>
# <link rel="Canonical" href="http://buy.sinyi.com.tw/house/42070W.html"/><meta http-equiv="content-language" content="zh-tw">
# <meta http-equiv="content-type" content="text/html; charset=utf-8" />
# <title>[è²·å±]ä¸­ç§æåç¶ ç¾å¢å°ä¸­å¸è¥¿å±¯åç¦éè·¯âä¿¡ç¾©æ¿å±å®å±ç¶²</title>
# ...

# %%
# type(res.text) : unicode
resp = res.text
re.sub('\n', '', resp)
print resp
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <script>(function(w,d,s,l,i){w[l]={'start':new Date().getTime(),id:i};
# var f=d.getElementsByTagName(s)[0],j=d.createElement(s);j.async=true;
# j.src='//img.sinyi.com/j/'+l+'.js';f.parentNode.insertBefore(j,f);
# })(window,document,'script','sy','57d3b79b8c73ec45432eaf27');</script>
#
# <script type="text/javascript">
# 	var krpano_obj_code = '42070W';
# 	var new_image_dir = "http://img.sinyi.com/i/new_item_page";
# </script>
# <link rel="Canonical" href="http://buy.sinyi.com.tw/house/42070W.html"/><meta http-equiv="content-language" content="zh-tw">
# <meta http-equiv="content-type" content="text/html; charset=utf-8" />
# <title>[è²·å±]ä¸­ç§æåç¶ ç¾å¢å°ä¸­å¸è¥¿å±¯åç¦éè·¯âä¿¡ç¾©æ¿å±å®å±ç¶²</title>
# ...

# %%
centerX_str = 'var centerX = "\d+.\d+"'
m = re.search(centerX_str, res.text)
mx = str(m.group())
# type(mx) : str
centerX = mx[15:25]
print centerX
# Out:
# 120.625523

# %%
centerY_str = 'var centerY = "\d+.\d+"'
m1 = re.search(centerY_str, res.text)
my = str(m1.group())
# type(my) : str
centerY = my[15:24]
print centerY
# Out:
# 24.195762
