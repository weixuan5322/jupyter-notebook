# %%
# 複習一下怎麼使用python的requests模組來request一個網頁

# %%
import requests as r
from bs4 import BeautifulSoup

# %%
r.get("https://google.com")
# Out:
# <Response [200]>

# %%
# 如果是Javascript渲染的頁面呢？

# %%
# 1.使用selenium(http://www.seleniumhq.org)
# 搭配好用的selenium 編輯器（Firefox插件）http://www.seleniumhq.org/projects/ide/

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

driver = webdriver.Firefox()
driver.get("https://www.agoda.com/zh-tw/")

driver.find_element_by_xpath("//input[@type='text']").click()
driver.find_element_by_xpath("//input[@type='text']").send_keys(u"台南")
driver.find_element_by_xpath("//button[@type='submit']").click()
driver.implicitly_wait(5)
html_source = driver.page_source
with open('./result.html', 'w') as f:
    f.write(html_source.encode('utf-8'))
#soup = BeautifulSoup(html_source, 'lxml')
# for x in range(0,3):
#     element = driver.find_element_by_id("paginationNext")
#     driver.execute_script("return arguments[0].scrollIntoView();", element)
#     element.click()

# %%
print html_source
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7 ]> <html lang="zh" class="ie6 no-js" dir="ltr"> <![endif]-->
# <!--[if IE 7 ]> <html lang="zh" class="ie7 no-js" dir="ltr"> <![endif]-->
# <!--[if IE 8 ]> <html lang="zh" class="ie8 no-js" dir="ltr"> <![endif]-->
# <!--[if IE 9 ]> <html lang="zh" class="ie9 no-js" dir="ltr"> <![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!-->
# <html xmlns="http://www.w3.org/1999/xhtml" lang="zh" dir="ltr" class="js supports csstransforms3d csstransitions flexbox"><!--<![endif]--><head><script type="text/javascript" async="" src="//nebula-cdn.kampyle.com/resources/onsite/js/cool-2.1.15.min.js"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/plugins/ua/linkid.js"></script><script type="text/javascript" async="" src="//ssl.mousestats.com/js/5/0/5045475514411081634.js" id="utag_220"></script><script type="text/javascript" async="" src="//www.google-analytics.com/analytics.js" id="tealium-tag-7110"></script><script type="text/javascript" async="" src="https://nebula-cdn.kampyle.com/wu/71154/onsite/embed.js" id="utag_440"></script>
#
#
# <script src="//tags.tiqcdn.com/utag/agoda/main/prod/utag.js" type="text/javascript" async=""></script><script type="text/javascript">
#         (function(n){"use strict";var t=function(t,i,r){function l(n){if(f.body)return n();setTimeout(function(){l(n)})}function c(){u.addEventListener&amp;&amp;u.removeEventListener("load",c);u.media=r||"all"}var f=n.document,u=f.createElement("link"),e,s,h,o;return i?e=i:(s=(f.body||f.getElementsByTagName("head")[0]).childNodes,e=s[s.length-1]),h=f.styleSheets,u.rel="stylesheet",u.href=t,u.media="only x",l(function(){e.parentNode.insertBefore(u,i?e:e.nextSibling)}),o=function(n){for(var i=u.href,t=h.length;t--;)if(h[t].href===i)return n();setTimeout(function(){o(n)})},u.addEventListener&amp;&amp;u.addEventListener("load",c),u.onloadcssdefined=o,o(c),u};typeof exports!="undefined"?exports.loadCSS=t:n.loadCSS=t})(typeof global!="undefined"?global:this),function(n){var t,i;n.loadCSS&amp;&amp;(t=loadCSS.relpreload={},t.support=function(){try{return n.document.createElement("link").relList.supports("preload")}catch(t){return!1}},t.poly=function(){for(var r=n.document.getElementsByTagName("link"),t,i=0;i&lt;r.length;i++)t=r[i],t.rel==="preload"&amp;&amp;t.getAttribute("as")==="style"&amp;&amp;(n.loadCSS(t.href,t),t.rel=null)},t.support()||(t.poly(),i=n.setInterval(t.poly,300),n.addEventListener&amp;&amp;n.addEventListener("load",function(){t.poly();n.clearInterval(i)}),n.attachEvent&amp;&amp;n.attachEvent("onload",function(){n.clearInterval(i)})))}(this)
# </script>        <style>@charset "UTF-8";.ficon,i.icon{display:inline-block}.ficon,body{font-style:normal}a,body a{background-color:transparent}.form-group dd,.nav&gt;li,.nav&gt;li&gt;a{position:relative}.flag,i.icon{background-repeat:no-repeat}.clearfix:after,.container-agoda:after,.nav:after,.navbar-header:after,.navbar-menu-item&gt;a:after{clear:both}body ul{list-style:none;outline:0;padding:0}body{font-weight:300;white-space:normal}@media (min-width:1100px){body .container-agoda{width:1100px;padding:0}}@media (max-width:1024px){body .container-agoda{width:940px;padding:0}}body a{text-decoration:none;color:#0283df}.main-header{height:60px;margin:0 auto 20px;color:#666;box-shadow:0 0 8px 2px rgba(0,0,0,.3)}.main-header .logo{float:left;margin-top:12px}.main-header .logo img{width:84px;height:35px}.main-header .navbar-header{width:100%}i.icon{background-size:initial}i.icon-clear{width:15px;height:15px;background-position:0 -120px}i.icon-calendar{width:25px;height:25px;background-position:-191px -139px}i.icon-dropdown-arrow{width:18px;height:25px;background-position:-467px -33px;top:5px;right:5px}header .navbar-header .ficon{vertical-align:top;text-align:center}.btn,.ficon,img{vertical-align:middle}.form-control{text-align:left}.btn,.text-center{text-align:center}body&gt;header.navbar-agoda{position:relative;z-index:110;width:100%}.ficon,button{text-transform:none}img{border:0}.ficon{-moz-osx-font-smoothing:grayscale;font-family:icons;line-height:1;font-weight:400;speak:none;text-decoration:inherit;text-rendering:optimizeLegibility;-webkit-font-smoothing:antialiased;margin-bottom:3px}.MIN-5571 .navbar-menu-item.sign-in-up&gt;.sign-in,a{text-decoration:none}.navbar-menu,.pointsmax-partner-list{list-style-type:none}.ficon-16{font-size:16px}.ficon-24{font-size:24px}.ficon-32{font-size:32px}.ficon-desktop-ic-black-down:before{content:"\f105"}.ficon-pointsmax-logo:before{content:"\f1eb"}.ficon-tooltip:before{content:"\f23f"}.ficon-user-font-icon:before{content:"\f24e"}html{font-family:sans-serif;-ms-text-size-adjust:100%;-webkit-text-size-adjust:100%}article,figcaption,figure,header,section{display:block}a{color:#337ab7}.form-control,body{background-color:#fff}h1{margin:.67em 0}h1,h2,h3,h6,ul{margin-bottom:10px}button,input{color:inherit;font:inherit;margin:0}button{overflow:visible;-webkit-appearance:button}button::-moz-focus-inner,input::-moz-focus-inner{border:0;padding:0}.btn,.form-control{background-image:none}body{line-height:1.42857;color:#333}*,:after,:before{box-sizing:border-box}html{font-size:10px}button,input{font-size:inherit;line-height:inherit}figure{margin:0}h1,h2,h3,h6{font-family:inherit;font-weight:500;line-height:1.1;color:inherit}h1,h2,h3{margin-top:20px}h1{font-size:36px}h2{font-size:30px}h3{font-size:24px}h6{margin-top:10px;font-size:12px}.btn,.form-control{padding:6px 12px;font-size:14px;line-height:1.42857}p{margin:0 0 10px}dt{font-weight:700}dl,ul{margin-top:0}dl{margin-bottom:20px}ul ul{margin-bottom:0}dd,dt{line-height:1.42857}dd{margin-left:0}@media (min-width:768px){.container-agoda{width:750px}.navbar-header{float:left}}.container-agoda:after,.container-agoda:before{display:table;content:" "}.container-agoda{margin-right:auto;margin-left:auto}@media (min-width:992px){.container-agoda{width:970px}}@media (min-width:1200px){.container-agoda{width:1170px}}.form-control{color:#555;display:block;width:100%;height:34px;border:1px solid #ccc;border-radius:4px;box-shadow:inset 0 1px 1px rgba(0,0,0,.075)}.form-control::-moz-placeholder{color:#999;opacity:1}.form-control:-ms-input-placeholder{color:#999}.form-control::-webkit-input-placeholder{color:#999}.form-control[readonly]{background-color:#eee;opacity:1}.form-group{margin-bottom:15px}.btn,.nav{margin-bottom:0}.btn{display:inline-block;font-weight:400;-ms-touch-action:manipulation;touch-action:manipulation;border:1px solid transparent;white-space:nowrap;border-radius:4px}.btn-default{color:#333;background-color:#fff;border-color:#ccc}.btn-primary{color:#ff ...
#  <script></script>
#
#         <meta content="IE=edge" http-equiv="X-UA-Compatible" />
#         <meta charset="utf-8" />
#
#
# <link crossorigin="" href="https://cdn6.agoda.net" rel="preconnect" /><link crossorigin="" href="https://pix6.agoda.net" rel="preconnect" />
#
#
#     <title>國內外特惠住宿線上訂房：訂飯店、找民宿、住Villa｜Agoda.com</title>
#     <meta content="index, follow" name="robots" />
#     <meta content="蒐羅全球930,039間住宿不折不賣保證最低價，提供全中文訂房服務，無論天涯海角一經線上訂房即等同確認訂單。24小時中英客服支援，讓你出門，只管玩就行了！" name="description" />
#     <meta content="Agoda, 飯店預訂, 飯店預訂, 飯店訂房, 預訂, 訂房,  亞洲地區, 歐洲地區, 美洲地區,  泰國, 曼谷, 美國, 中國, 上海, 日本, 東京,  馬來西亞, 新加坡, 韓國, 加拿大, 英國, 荷蘭, 法國, 紐西蘭, 澳洲, 優惠價格, 飯店評論 網路預訂, 地圖, 渡假村, 度假村" name="keywords" />
#     <link href="https://www.agoda.com/zh-tw/" rel="canonical" />
#     <link title="English" hreflang="x-default" href="https://www.agoda.com/" rel="alternate" />
#     <link title="Français" hreflang="fr-fr" href="https://www.agoda.com/fr-fr/" rel="alternate" />
#     <link title="Deutsch" hreflang="de-de" href="https://www.agoda.com/de-de/" rel="alternate" />
#     <link title="Italiano" hreflang="it-it" href="https://www.agoda.com/it-it/" rel="alternate" />
#     <link title="Español" hreflang="es-es" href="https://www.agoda.com/es-es/" rel="alternate" />
#     <link title="日本語" hreflang="ja-jp" href="https://www.agoda.com/ja-jp/" rel="alternate" />
#     <link title="繁體中文 (香港)" hreflang="zh-hk" href="https://www.agoda.com/zh-hk/" rel="alternate" />
#     <link title="简体中文" hreflang="zh-cn" href="https://www.agoda.com/zh-cn/" rel="alternate" />
#     <link title="한국어" hreflang="ko-kr" href="https://www.agoda.com/ko-kr/" rel="alternate" />
#     <link title="Ελληνικά" hreflang="el-gr" href="https://www.agoda.com/el-gr/" rel="alternate" />
#     <link title="Русский" hreflang="ru-ru" href="https://www.agoda.com/ru-ru/" rel="alternate" />
#     <link title="Português" hreflang="pt-pt" href="https://www.agoda.com/pt-pt/" rel="alternate" />
#     <link title="Nederlands" hreflang="nl-nl" href="https://www.agoda.com/nl-nl/" rel="alternate" />
#     <link title="English / Canada" hreflang="en-ca" href="https://www.agoda.com/en-ca/" rel="alternate" />
#     <link title="English / India" hreflang="en-in" href="https://www.agoda.com/en-in/" rel="alternate" />
#     <link title="English / United Kingdom" hreflang="en-gb" href="https://www.agoda.com/en-gb/" rel="alternate" />
#     <link title="English / South-Africa" hreflang="en-za" href="https://www.agoda.com/en-za/" rel="alternate" />
#     <link title="English / Australia" hreflang="en-au" href="https://www.agoda.com/en-au/" rel="alternate" />
#     <link title="English / Singapore" hreflang="en-sg" href="https://www.agoda.com/en-sg/" rel="alternate" />
#     <link title="繁體中文 (台灣)" hreflang="zh-tw" href="https://www.agoda.com/zh-tw/" rel="alternate" />
#     <link title="English / New Zealand" hreflang="en-nz" href="https://www.agoda.com/en-nz/" rel="alternate" />
#     <link title="ภาษาไทย" hreflang="th-th" href="https://www.agoda.com/th-th/" rel="alternate" />
#     <link title="Bahasa Malaysia" hreflang="ms-my" href="https://www.agoda.com/ms-my/" rel="alternate" />
#     <link title="Tiếng Việt" hreflang="vi-vn" href="https://www.agoda.com/vi-vn/" rel="alternate" />
#     <link title="Svenska" hreflang="sv-se" href="https://www.agoda.com/sv-se/" rel="alternate" />
#     <link title="Bahasa Indonesia" hreflang="id-id" href="https://www.agoda.com/id-id/" rel="alternate" />
#     <link title="Język polski" hreflang="pl-pl" href="https://www.agoda.com/pl-pl/" rel="alternate" />
#     <link title="Norsk" hreflang="nb-no" href="https://www.agoda.com/nb-no/" rel="alternate" />
#     <link title="Dansk" hreflang="da-dk" href="https://www.agoda.com/da-dk/" rel="alternate" />
#     <link title="Suomi" hreflang="fi-fi" href="https://www.agoda.com/fi-fi/" rel="alternate" />
#     <link title="Čeština" hreflang="cs-cz" href="https://www.agoda.com/cs-cz/" rel="alternate" />
#     <link title="Türkçe" hreflang="tr-tr" href="https://www.agoda.com/tr-tr/" rel="alternate" />
#     <link title="Català" hreflang="ca-es" href="https://www.agoda.com/ca-es/" rel="alternate" />
#     <link title="Magyar" hreflang="hu-hu" href="https://www.agoda.com/hu-hu/" rel="alternate" />
#     <link title="हिन्दी" hreflang="hi-in" href="https://www.agoda.com/hi-in/" rel="alternate" />
#     <link title="Български език" hreflang="bg-bg" href="https://www.agoda.com/bg-bg/" rel="alternate" />
#     <link title="Română" hreflang="ro-ro" href="https://www.agoda.com/ro-ro/" rel="alternate" />
#     <link title="Slovenski jezik" hreflang="sl-si" href="https://www.agoda.com/sl-si/" rel="alternate" />
#     <link title="עברית" hreflang="he-il" href="https://www.agoda.com/he-il/" rel="alternate" />
#     <link title="العربية" hreflang="ar-ae" href="https://www.agoda.com/ar-ae/" rel="alternate" />
#     <link title="Nederlands / België" hreflang="nl-be" href="https://www.agoda.com/nl-be/" rel="alternate" />
#     <link title="English / Ireland" hreflang="en-ie" href="https://www.agoda.com/en-ie/" rel="alternate" />
#     <link title="Português / Brasil" hreflang="pt-br" href="https://www.agoda.com/pt-br/" rel="alternate" />
#     <link title="Español / Argentina" hreflang="es-ar" href="https://www.agoda.com/es-ar/" rel="alternate" />
#     <link title="Español / México" hreflang="es-mx" href="https://www.agoda.com/es-mx/" rel="alternate" />
#     <link title="Lietuvių" hreflang="lt-lt" href="https://www.agoda.com/lt-lt/" rel="alternate" />
#     <link title="Latviešu" hreflang="lv-lv" href="https://www.agoda.com/lv-lv/" rel="alternate" />
#     <link title="Hrvatski" hreflang="hr-hr" href="https://www.agoda.com/hr-hr/" rel="alternate" />
#     <link title="Eesti" hreflang="et-ee" href="https://www.agoda.com/et-ee/" rel="alternate" />
#     <link title="Українська" hreflang="uk-ua" href="https://www.agoda.com/uk-ua/" rel="alternate" />
#
#     <meta content="Agoda" property="og:site_name" />
#     <meta content="161134343906646" property="fb:app_id" />
#     <meta content="國內外特惠住宿線上訂房：訂飯店、找民宿、住Villa｜Agoda.com" property="og:title" />
#     <meta content="https://cdn6.agoda.net/images/mvc/default/agoda-logo-flat.png" property="og:image" />
#     <meta content="https://www.agoda.com/zh-tw/" property="og:url" />
#     <meta content="蒐羅全球930,039間住宿不折不賣保證最低價，提供全中文訂房服務，無論天涯海角一經線上訂房即等同確認訂單。24小時中英客服支援，讓你出門，只管玩就行了！" property="og:description" />
#     <meta content="website" property="og:type" />
#     <meta content="summary" name="twitter:card" />
#     <meta content="@agoda" name="twitter:site" />
#     <meta content="@agoda" name="twitter:creator" />
#     <meta content="國內外特惠住宿線上訂房：訂飯店、找民宿、住Villa｜Agoda.com" name="twitter:title" />
#     <meta content="蒐羅全球930,039間住宿不折不賣保證最低價，提供全中文訂房服務，無論天涯海角一經線上訂房即等同確認訂單。24小時中英客服支援，讓你出門，只管玩就行了！" name="twitter:description" />
#     <meta content="https://www.agoda.com/zh-tw/" name="twitter:url" />
#     <meta content="https://cdn6.agoda.net/images/mvc/default/agoda-logo-flat.png" name="twitter:image" />
#
#
#
#
#
#
#         <link rel="stylesheet" href="https://cdn6.agoda.net/images/mvc/styles/assets/layout-7f33d3005c.strDomain.css" media="all" /><link onload="this.rel = 'stylesheet'" as="style" href="https://cdn6.agoda.net/images/mvc/styles/assets/layout-7f33d3005c.strDomain.css" rel="null" /><noscript>&lt;link rel="stylesheet" href="https://cdn6.agoda.net/images/mvc/styles/assets/layout-7f33d3005c.strDomain.css"&gt;</noscript>
#
#
# <script id="JsExpDetermination" type="text/javascript">
# !function(){function b(){var b=new a;return b}Array.prototype.indexOf||(Array.prototype.indexOf=function(a,b){null==b?b=0:0&gt;b&amp;&amp;(b=Math.max(0,this.length+b));for(var c=b,d=this.length;d&gt;c;c++)if(this[c]===a)return c;return-1});var a=function(){this.mapping=[]};a.prototype.isB=function(a){return null==this.mapping||this.mapping.constructor!==Array?!1:this.mapping.indexOf(a)&gt;-1},"undefined"!=typeof module&amp;&amp;"undefined"!=typeof module.exports?module.exports=b():"function"==typeof define&amp;&amp;define.amd?define([],function(){return b()}):window.ExperimentManager=b()}();
# </script>
#
#
#
# <script crossorigin="anonymous" src="https://cdn6.agoda.net/js/mvc/scripts-newsite-init-7ef4b49bb0.js"></script>
#
# <script type="text/javascript">
#                 TraceKit&amp;&amp;TraceKit.report.subscribe(function(n){try{n.stack||(n.stack=new Error("make stack").stack,n.stack&amp;&amp;(n.stack=n.stack.toString()))}catch(i){}try{n="string"!=typeof n?JSON.stringify(n):n;var t=new XMLHttpRequest;t.open("POST","/api/rum/pe",!0);t.setRequestHeader("Content-Type","application/json;charset=UTF-8");t.send(JSON.stringify({error:n,page:"newhome"}))}catch(r){}})
# </script>
#
#
#     <link rel="stylesheet" href="https://cdn6.agoda.net/images/mvc/styles/layout-e5c4b04dff.strDomain.css" media="all" /><link onload="this.rel = 'stylesheet'" as="style" href="https://cdn6.agoda.net/images/mvc/styles/layout-e5c4b04dff.strDomain.css" rel="null" /><noscript>&lt;link rel="stylesheet" href="https://cdn6.agoda.net/images/mvc/styles/layout-e5c4b04dff.strDomain.css"&gt;</noscript>
#
# <meta content="app-id=440676901" name="apple-ios-itunes-app" />
# <meta content="app-id=440676901" name="google-play-app" />
#
# <script type="application/ld+json">
#     {
#         "@context" : "http://schema.org",
#         "@type" : "Organization",
#         "name" : "Agoda.com",
#         "url" : "http://www.agoda.com",
#         "logo" : "https://cdn6.agoda.net/images/MVC/default/logo-agoda-mobile.png",
#         "sameAs" : ["https://www.facebook.com/agoda",
#                 "https://instagram.com/agoda",
#                 "https://www.linkedin.com/company/agoda",
#                 "https://www.twitter.com/agoda",
#                 "https://plus.google.com/+Agoda"]
#     }
# </script>
#
#
#         <link rel="stylesheet" href="https://cdn6.agoda.net/images/mvc/styles/assets/home/index/entry-bbae3adef2.strDomain.css" media="all" /><link onload="this.rel = 'stylesheet'" as="style" href="https://cdn6.agoda.net/images/mvc/styles/assets/home/index/entry-bbae3adef2.strDomain.css" rel="null" /><noscript>&lt;link rel="stylesheet" href="https://cdn6.agoda.net/images/mvc/styles/assets/home/index/entry-bbae3adef2.strDomain.css"&gt;</noscript>
#
#
#         <!--[if IE 7]><link rel="preload" href="https://cdn6.agoda.net/images/mvc/styles/assets/ie7-fdb71cac7f.strDomain.css" as="style" onload="this.rel = 'stylesheet'"><noscript><link rel="stylesheet" href="https://cdn6.agoda.net/images/mvc/styles/assets/ie7-fdb71cac7f.strDomain.css"></noscript>
# <![endif]-->
#         <!--[if IE 8]><link rel="preload" href="https://cdn6.agoda.net/images/mvc/styles/assets/ie8-d920eb763f.strDomain.css" as="style" onload="this.rel = 'stylesheet'"><noscript><link rel="stylesheet" href="https://cdn6.agoda.net/images/mvc/styles/assets/ie8-d920eb763f.strDomain.css"></noscript>
# <![endif]-->
#
#
#
#         <link rel="stylesheet" href="https://cdn6.agoda.net/images/mvc/styles/experiment-desktop-home-57c7ad212b.strDomain.css" media="all" /><link onload="this.rel = 'stylesheet'" as="style" href="https://cdn6.agoda.net/images/mvc/styles/experiment-desktop-home-57c7ad212b.strDomain.css" rel="null" /><noscript>&lt;link rel="stylesheet" href="https://cdn6.agoda.net/images/mvc/styles/experiment-desktop-home-57c7ad212b.strDomain.css"&gt;</noscript>
#
#
# <script type="text/x-handlebars-template" id="login_popup_template">
# &lt;div id="login-popup" class="login-popup" data-selenium="login-popup"&gt;
#
# &lt;div id="signin-panel" class="signin-panel" data-selenium="signin-panel"&gt;
#     &lt;div id="signin-panel-header" class="signin-panel-header" data-selenium="signin-panel-header"&gt;
#         &lt;div class="close-panel"&gt;
#             &lt;i class="close-popup" data-selenium="signin-close-icon"&gt;&lt;/i&gt;
#         &lt;/div&gt;
#         &lt;h3 data-selenium="signin-header-text"&gt;Agoda會員登入&lt;/h3&gt;
#     &lt;/div&gt;
#
#     &lt;form id="signin-panel-form" data-selenium="signin-panel-form"&gt;
#         &lt;div id="signin-panel-body" class="signin-panel-body" data-selenium="signin-panel-body"&gt;
#             &lt;div id="signin-respond-warning-email-password-incorrect" class="respond-warning" data-selenium="signin-alert-panel-email-password-incorect"&gt;
#                電子信箱或密碼輸入錯誤。
#                &lt;a href="https://my.agoda.com/zh-tw/login-problems.html"&gt;忘了密碼？別慌！點此找幫手&lt;/a&gt;
#             &lt;/div&gt;
#             &lt;div id="sign-in-alert-info-before-contact-host" class="alert alert-info" data-selenium="sign-in-alert-info-before-contact-host" style="display:none;"&gt;
#                 請先登入會員，這樣我們才知道如何回覆您喔！
#             &lt;/div&gt;
#             &lt;div class="row"&gt;
#                 &lt;div id="signin-email-section" class="col-xs-6 email-section"&gt;
#                     &lt;div id="signin-email-label" data-selenium="signin-email-label"&gt;電子信箱: &lt;em&gt;*&lt;/em&gt;&lt;/div&gt;
#                     &lt;input tabindex="1"  data-selenium="signin-email-input" type="text" class="text required" name="signin-email-input" id="signin-email-input"&gt;
#                     &lt;div id="signin-email-blank" class="feedback-warning" data-selenium="signin-email-blank"&gt;
#                         電子信箱為必填資訊。
#                     &lt;/div&gt;
#                     &lt;div id="signin-email-wrong-format" class="feedback-warning" data-selenium="signin-email-wrong-format"&gt;
#                         您輸入之電子信箱格式不符合規範。
#                     &lt;/div&gt;
#                 &lt;/div&gt;
#
#                 &lt;div id="signin-password-section" class="col-xs-6 password-section"&gt;
#                     &lt;div id="signin-password-label" data-selenium="signin-password-label"&gt;輸入密碼: &lt;em&gt;*&lt;/em&gt;&lt;/div&gt;
#                     &lt;input tabindex="2"  data-selenium="signin-password-input" type="password" class="text required" name="signin-password-input" id="signin-password-input"&gt;
#                     &lt;div id="signin-password-blank" class="feedback-warning" data-selenium="signin-password-blank"&gt;
#                         密碼為必填欄位
#                     &lt;/div&gt;
#                 &lt;/div&gt;
#             &lt;/div&gt;
#         &lt;/div&gt;
#
#         &lt;div id="signin-action-panel" class="signin-action-panel" data-selenium="signin-action-panel"&gt;
#             &lt;div class="link-action-panel"&gt;
#                 &lt;div&gt;&lt;a href="https://my.agoda.com/zh-tw/login-problems.html?ckuid=a084d4d7-f152-4cfd-95e6-8ec92e340273" data-selenium="forget-password-link"&gt;忘了密碼？別慌！點此找幫手&lt;/a&gt;&lt;/div&gt;
#                 &lt;div&gt; 是新朋友嗎？&lt;a id='signup-action' class='toggle-link' data-selenium='signup-action'&gt;點此入會&lt;/a&gt;&lt;/div&gt;
#             &lt;/div&gt;
#             &lt;div class="button-action-panel"&gt;
#                 &lt;i id="signin-loading-icon" class="signin-loading-icon" data-selenium="signin-loading-icon"&gt;&lt;/i&gt;
#                 &lt;input data-selenium="signin-submit-button" type="submit" name="signin-submit-button" value="登入" id="signin-submit-button" class="action-button"&gt;
#             &lt;/div&gt;
#         &lt;/div&gt;
#     &lt;/form&gt;
# &lt;/div&gt;
#
# &lt;div id="signup-panel" class="signup-panel" data-selenium="signup-panel"&gt;
#     &lt;div id="signup-panel-header" class="signup-panel-header" data-selenium="signup-panel-header"&gt;
#         &lt;div class="close-panel"&gt;
#             &lt;i class="close-popup" data-selenium="signup-close-icon"&gt;&lt;/i&gt;
#         &lt;/div&gt;
#         &lt;h3 data-selenium="signup-header-text"&gt;Agoda會員可享隱藏版特惠價！&lt;/h3&gt;
#     &lt;/div&gt;
#
#     &lt;form id="signup-panel-form" data-selenium="signup-panel-form"&gt;
#         &lt;div id="signup-panel-body" class="signup-panel-body" data-selenium="signup-panel-body"&gt;
#             &lt;div id="signup-respond-technical-difficulties-issue" class="respond-warning" data-selenium="signup-respond-technical-difficulties-issue"&gt;
#                抱歉，目前發生技術性問題。
#             &lt;/div&gt;
#             &lt;div class="row"&gt;
#                 &lt;div class="col-xs-6 email-section"&gt;
#                     &lt;div id="signup-firstname-label" data-selenium="signup-firstname-label"&gt;護照英文名 (例: Da Ming): &lt;em&gt;*&lt;/em&gt;&lt;/div&gt;
#                     &lt;input tabindex="1"  data-selenium="signup-firstname-input" type="text" class="text required" name="signup-firstname-input" id="signup-firstname-input" maxlength="64"&gt;
#                     &lt;div id="signup-firstname-blank" class="feedback-warning" data-selenium="signup-firstname-blank"&gt;
#                         「名」為必填資訊
#                     &lt;/div&gt;
#                     &lt;div id="signup-firstname-in-english" class="feedback-warning" data-selenium="signup-firstname-in-english"&gt;
#                         請務必使用英文輸入。
#                     &lt;/div&gt;
#                 &lt;/div&gt;
#                 &lt;div class="col-xs-6 password-section"&gt;
#                     &lt;div id="signup-lastname-label" data-selenium="signup-lastname-label"&gt;護照英文姓 (例: Wang): &lt;em&gt;*&lt;/em&gt;&lt;/div&gt;
#                     &lt;input tabindex="2"  data-selenium="signup-lastname-input" type="text" class="text required" name="signup-lastname-input" id="signup-lastname-input" maxlength="64"&gt;
#                     &lt;div id="signup-lastname-blank" class="feedback-warning" data-selenium="signup-lastname-blank"&gt;
#                         需要填寫姓氏。
#                     &lt;/div&gt;
#                     &lt;div id="signup-lastname-in-english" class="feedback-warning" data-selenium="signup-lastname-in-english"&gt;
#                         請務必使用英文輸入。
#                     &lt;/div&gt;
#                 &lt;/div&gt;
#             &lt;/div&gt;
#
#             &lt;div class="row"&gt;
#                 &lt;div class="col-xs-6 email-section"&gt;
#                     &lt;div id="signup-email-label" data-selenium="signup-email-label"&gt;電子信箱: &lt;em&gt;*&lt;/em&gt;&lt;/div&gt;
#                     &lt;i id="signup-email-verification-icon" class="signup-email-verification-icon" data-selenium="signup-email-verification-icon"&gt;&lt;/i&gt;
#                     &lt;input tabindex="3"  data-selenium="signup-email-input" type="text" class="text required" name="signup-email-input" id="signup-email-input" maxlength="64"&gt;
#                     &lt;div id="signup-email-blank" class="feedback-warning" data-selenium="signup-email-blank"&gt;
#                         電子信箱為必填資訊。
#                     &lt;/div&gt;
#                     &lt;div id="signup-email-wrong-format" class="feedback-warning" data-selenium="signup-email-wrong-format"&gt;
#                         您輸入之電子信箱格式不符合規範。
#                     &lt;/div&gt;
#                     &lt;div id="signup-email-exist" class="feedback-warning" data-selenium="signup-email-exist"&gt;
#                         此電子郵件已被使用。
#                     &lt;/div&gt;
#                 &lt;/div&gt;
#                 &lt;div class="col-xs-6 password-section"&gt;
#                     &lt;div id="signup-password-label" data-selenium="signup-password-label"&gt;輸入密碼: &lt;em&gt;*&lt;/em&gt;&lt;/div&gt;
#                     &lt;input tabindex="4"  data-selenium="signup-password-input" type="password" class="text required" name="signup-password-input" id="signup-password-input" maxlength="64"&gt;
#                     &lt;div id="signup-password-blank" class="feedback-warning" data-selenium="signup-password-blank"&gt;
#                         密碼為必填欄位
#                     &lt;/div&gt;
#                     &lt;div id="signup-password-short" class="feedback-warning" data-selenium="signup-password-short"&gt;
#                         密碼可用大小寫英文字母混合符號，最少需有8個字元。
#                     &lt;/div&gt;
#                 &lt;/div&gt;
#             &lt;/div&gt;
#
#             &lt;div class="row"&gt;
#                 &lt;div class="send-me-offer-section"&gt;
#                     &lt;input data-selenium="send-me-special-offer-input" type="checkbox" class="send-me-offer-checkbox" id="send-me-special-offer-input" name="send-me-special-offer-input" checked="checked"&gt;
#                     &lt;span data-selenium="send-me-special-offer-label" id="send-me-special-offer-label"&gt;我想要接收優惠電子報&lt;/span&gt;
#                 &lt;/div&gt;
#             &lt;/div&gt;
#         &lt;/div&gt;
#
#         &lt;div id="signup-action-panel" class="signup-action-panel" data-selenium="signup-action-panel"&gt;
#             &lt;div class="link-action-panel"&gt;
#                 &lt;div&gt;已經是會員？&lt;a id='signin-action' class='toggle-link' data-selenium='signin-action'&gt;點此登入&lt;/a&gt;&lt;/div&gt;
#             &lt;/div&gt;
#             &lt;div class="button-action-panel"&gt;
#                 &lt;i id="z-loading-icon" class="signup-loading-icon" data-selenium="signup-loading-icon"&gt;&lt;/i&gt;
#                 &lt;input data-selenium="signup-submit-button" type="submit" name="signup-submit-button" value="加入會員" id="signup-submit-button" class="action-button"&gt;
#             &lt;/div&gt;
#         &lt;/div&gt;
#     &lt;/form&gt;
# &lt;/div&gt;
# &lt;/div&gt;
# </script>    <script type="text/javascript" async="" src="//tags.tiqcdn.com/utag/agoda/main/prod/utag.102.js?utv=201510270729" id="utag_agoda.main_102"></script><script type="text/javascript" async="" src="//tags.tiqcdn.com/utag/agoda/main/prod/utag.220.js?utv=201510270729" id="utag_agoda.main_220"></script><script type="text/javascript" async="" src="//tags.tiqcdn.com/utag/agoda/main/prod/utag.333.js?utv=201606300515" id="utag_agoda.main_333"></script><script type="text/javascript" async="" src="//tags.tiqcdn.com/utag/agoda/main/prod/utag.440.js?utv=201606210755" id="utag_agoda.main_440"></script><script type="text/javascript" async="" src="//tags.tiqcdn.com/utag/agoda/main/prod/utag.284.js?utv=201605121112" id="utag_agoda.main_284"></script><script type="text/javascript" async="" src="//tags.tiqcdn.com/utag/tiqapp/utag.v.js?a=agoda/main/201608251206&amp;cb=1472132941465" id="tiqapp"></script><style type="text/css" id="kampyleStyle">.noOutline{outline: none !important;}</style><script type="text/javascript" async="" src="//screencaptue-cdn.kampyle.com/js/11443/usersnap2-11443-en.js"></script></head>
#
#       <body class="HALO-2908 HALO-3015 HALO-3150 MALLORY MIN-5555 MIN-5571 MIN-5891 MIN-6143 NEWROOMGROUPING PRIUS-1576 PRIUS-1662 SEAR-50 SEAR-798 newhome desktop ">
#
#
#         <input type="hidden" value="False" id="mockDataEnabled" name="mockDataEnabled" />
#         <div data-device="desktop" data-page="newhome" id="page-identification" class="hide"></div>
#         <div data-url-version="" data-language-domain="" data-page-type-id="1" data-store-front-id="3" data-culture="zh-tw" data-origin="TW" data-real-language-id="20" data-language-id="20" class="hide" id="hidden-routeinfo"></div>
#
#
#
#
#
#
#
#
#
#
#
#
# <header class="navbar-agoda main-header scrollTo " data-selenium="page-header" id="page-header">
#     <div class="navbar-header">
#         <div class="container-agoda">
#
# <div itemscope="" itemtype="http://schema.org/Organization" class="logo" data-selenium="header-logo">
#     <a href="/zh-tw?cid=-1" itemprop="url" title="Smarter hotel booking">
#         <img alt="Agoda" title="Agoda" itemprop="logo" data-2x="https://cdn6.agoda.net/images/MVC/default/agoda-logo@2X.png" src="https://cdn6.agoda.net/images/MVC/default/agoda-logo.png" />
#     </a>
# </div>
#
#
#
#
#     <div data-selenium="header-contact-number-container" class="container-navbar-contact-number">
#         <span data-selenium="header-contact-service" class="navbar-customer-service">客服專線:</span>
#         <i data="20" class="flag flag-18 flag-18-tw contact-number-flag"></i>
#         <span data-selenium="header-contact-number" class="navbar-contact-number">02 8723 1285</span>
#     </div>
#
#
#             <ul data-selenium="header-mainmenu" id="header-mainmenu" class="navbar-menu">
#
#
#
# <li id="feedback-menu" class="navbar-menu-item" style="display: list-item;">
#     <a title="歡迎和我們分享Agoda網頁使用體驗" id="feedback-menu-icon" class="feedback-menu-icon" data-selenium="feedback-menu">
#         <i class="ficon ficon-24 ficon-tooltip"></i>
#
#     </a>
#     <div data-selenium="feedback-panel" class="feedback-panel" style="display: none;">
#         <div data-id="4411" id="website-feedback-panel">歡迎和我們分享Agoda網頁使用體驗</div>
#     </div>
# </li>
#
#
#                 <!-- TODO: Fix js about control the popup-->
#
#
#
#                 <li class="navbar-menu-item">
#                     <a data-toggle="dropdown" title="zh-tw" id="language" class="language anchor" data-selenium="language">
#                         <i data-language="20" class="flag flag-18 flag-18-tw"></i>
#                     </a>
#
#     <div id="languages-panel" class="languages" style="display: none;">
#         <div class="" id="suggested-language" data-selenium="suggested-language" style="display: block;">
#             <span>語言快捷選項</span>
#             <ul class="languages-list">
#
#         <li>
#             <a title="繁體中文 (台灣)" class="language-item anchor" data-selenium="menu-language20">
#                 <i uiculture="zh-tw" data="20" class="flag flag-18 flag-18-tw zh-tw"></i>
#                 繁體中文 (台灣)
#             </a>
#         </li>
# </ul>
#         </div>
#         <div class="" id="all-languages" data-selenium="all-languages" style="display: block;">
#             <span>所有語言</span>
#             <ul class="languages-list">
#
#         <li>
#             <a title="English" class="language-item anchor" data-selenium="menu-language1">
#                 <i uiculture="en-us" data="1" class="flag flag-18 flag-18-us en-us"></i>
#                 English
#             </a>
#         </li>
#
#         <li class="selected">
#             <a title="繁體中文 (台灣)" class="language-item anchor" data-selenium="menu-language20">
#                 <i uiculture="zh-tw" data="20" class="flag flag-18 flag-18-tw zh-tw"></i>
#                 繁體中文 (台灣)
#             </a>
#         </li>
#
#         <li>
#             <a title="Magyar" class="language-item anchor" data-selenium="menu-language34">
#                 <i uiculture="hu-hu" data="34" class="flag flag-18 flag-18-hu hu-hu"></i>
#                 Magyar
#             </a>
#         </li>
#
#         <li>
#             <a title="العربية" class="language-item anchor" data-selenium="menu-language40">
#                 <i uiculture="ar-ae" data="40" class="flag flag-18 flag-18-ae ar-ae"></i>
#                 العربية
#             </a>
#         </li>
#
#         <li>
#             <a title="ภาษาไทย" class="language-item anchor" data-selenium="menu-language22">
#                 <i uiculture="th-th" data="22" class="flag flag-18 flag-18-th th-th"></i>
#                 ภาษาไทย
#             </a>
#         </li>
#
#         <li>
#             <a title="हिन्दी" class="language-item anchor" data-selenium="menu-language35">
#                 <i uiculture="hi-in" data="35" class="flag flag-18 flag-18-in hi-in"></i>
#                 हिन्दी
#             </a>
#         </li>
#
#         <li>
#             <a title="Deutsch" class="language-item anchor" data-selenium="menu-language3">
#                 <i uiculture="de-de" data="3" class="flag flag-18 flag-18-de de-de"></i>
#                 Deutsch
#             </a>
#         </li>
#
#         <li>
#             <a title="Bahasa Malaysia" class="language-item anchor" data-selenium="menu-language23">
#                 <i uiculture="ms-my" data="23" class="flag flag-18 flag-18-my ms-my"></i>
#                 Bahasa Malaysia
#             </a>
#         </li>
#
#         <li>
#             <a title="Български език" class="language-item anchor" data-selenium="menu-language36">
#                 <i uiculture="bg-bg" data="36" class="flag flag-18 flag-18-bg bg-bg"></i>
#                 Български език
#             </a>
#         </li>
#
#         <li>
#             <a title="Italiano" class="language-item anchor" data-selenium="menu-language4">
#                 <i uiculture="it-it" data="4" class="flag flag-18 flag-18-it it-it"></i>
#                 Italiano
#             </a>
#         </li>
#
#         <li>
#             <a title="Tiếng Việt" class="language-item anchor" data-selenium="menu-language24">
#                 <i uiculture="vi-vn" data="24" class="flag flag-18 flag-18-vn vi-vn"></i>
#                 Tiếng Việt
#             </a>
#         </li>
#
#         <li>
#             <a title="Română" class="language-item anchor" data-selenium="menu-language37">
#                 <i uiculture="ro-ro" data="37" class="flag flag-18 flag-18-ro ro-ro"></i>
#                 Română
#             </a>
#         </li>
#
#         <li>
#             <a title="Español" class="language-item anchor" data-selenium="menu-language5">
#                 <i uiculture="es-es" data="5" class="flag flag-18 flag-18-es es-es"></i>
#                 Español
#             </a>
#         </li>
#
#         <li>
#             <a title="Svenska" class="language-item anchor" data-selenium="menu-language25">
#                 <i uiculture="sv-se" data="25" class="flag flag-18 flag-18-se sv-se"></i>
#                 Svenska
#             </a>
#         </li>
#
#         <li>
#             <a title="Slovenski jezik" class="language-item anchor" data-selenium="menu-language38">
#                 <i uiculture="sl-si" data="38" class="flag flag-18 flag-18-si sl-si"></i>
#                 Slovenski jezik
#             </a>
#         </li>
#
#         <li>
#             <a title="日本語" class="language-item anchor" data-selenium="menu-language6">
#                 <i uiculture="ja-jp" data="6" class="flag flag-18 flag-18-jp ja-jp"></i>
#                 日本語
#             </a>
#         </li>
#
#         <li>
#             <a title="Bahasa Indonesia" class="language-item anchor" data-selenium="menu-language26">
#                 <i uiculture="id-id" data="26" class="flag flag-18 flag-18-id id-id"></i>
#                 Bahasa Indonesia
#             </a>
#         </li>
#
#         <li>
#             <a title="עברית" class="language-item anchor" data-selenium="menu-language39">
#                 <i uiculture="he-il" data="39" class="flag flag-18 flag-18-il he-il"></i>
#                 עברית
#             </a>
#         </li>
#
#         <li>
#             <a title="繁體中文 (香港)" class="language-item anchor" data-selenium="menu-language7">
#                 <i uiculture="zh-hk" data="7" class="flag flag-18 flag-18-hk zh-hk"></i>
#                 繁體中文 (香港)
#             </a>
#         </li>
#
#         <li>
#             <a title="Język polski" class="language-item anchor" data-selenium="menu-language27">
#                 <i uiculture="pl-pl" data="27" class="flag flag-18 flag-18-pl pl-pl"></i>
#                 Język polski
#             </a>
#         </li>
#
#         <li>
#             <a title="Français" class="language-item anchor" data-selenium="menu-language2">
#                 <i uiculture="fr-fr" data="2" class="flag flag-18 flag-18-fr fr-fr"></i>
#                 Français
#             </a>
#         </li>
#
#         <li>
#             <a title="简体中文" class="language-item anchor" data-selenium="menu-language8">
#                 <i uiculture="zh-cn" data="8" class="flag flag-18 flag-18-cn zh-cn"></i>
#                 简体中文
#             </a>
#         </li>
#
#         <li>
#             <a title="Norsk" class="language-item anchor" data-selenium="menu-language28">
#                 <i uiculture="nb-no" data="28" class="flag flag-18 flag-18-no nb-no"></i>
#                 Norsk
#             </a>
#         </li>
#
#         <li>
#             <a title="Lietuvių" class="language-item anchor" data-selenium="menu-language46">
#                 <i uiculture="lt-lt" data="46" class="flag flag-18 flag-18-lt lt-lt"></i>
#                 Lietuvių
#             </a>
#         </li>
#
#         <li>
#             <a title="한국어" class="language-item anchor" data-selenium="menu-language9">
#                 <i uiculture="ko-kr" data="9" class="flag flag-18 flag-18-kr ko-kr"></i>
#                 한국어
#             </a>
#         </li>
#
#         <li>
#             <a title="Dansk" class="language-item anchor" data-selenium="menu-language29">
#                 <i uiculture="da-dk" data="29" class="flag flag-18 flag-18-dk da-dk"></i>
#                 Dansk
#             </a>
#         </li>
#
#         <li>
#             <a title="Latviešu" class="language-item anchor" data-selenium="menu-language47">
#                 <i uiculture="lv-lv" data="47" class="flag flag-18 flag-18-lv lv-lv"></i>
#                 Latviešu
#             </a>
#         </li>
#
#         <li>
#             <a title="Ελληνικά" class="language-item anchor" data-selenium="menu-language10">
#                 <i uiculture="el-gr" data="10" class="flag flag-18 flag-18-gr el-gr"></i>
#                 Ελληνικά
#             </a>
#         </li>
#
#         <li>
#             <a title="Suomi" class="language-item anchor" data-selenium="menu-language30">
#                 <i uiculture="fi-fi" data="30" class="flag flag-18 flag-18-fi fi-fi"></i>
#                 Suomi
#             </a>
#         </li>
#
#         <li>
#             <a title="Hrvatski" class="language-item anchor" data-selenium="menu-language48">
#                 <i uiculture="hr-hr" data="48" class="flag flag-18 flag-18-hr hr-hr"></i>
#                 Hrvatski
#             </a>
#         </li>
#
#         <li>
#             <a title="Русский" class="language-item anchor" data-selenium="menu-language11">
#                 <i uiculture="ru-ru" data="11" class="flag flag-18 flag-18-ru ru-ru"></i>
#                 Русский
#             </a>
#         </li>
#
#         <li>
#             <a title="Čeština" class="language-item anchor" data-selenium="menu-language31">
#                 <i uiculture="cs-cz" data="31" class="flag flag-18 flag-18-cz cs-cz"></i>
#                 Čeština
#             </a>
#         </li>
#
#         <li>
#             <a title="Eesti" class="language-item anchor" data-selenium="menu-language49">
#                 <i uiculture="et-ee" data="49" class="flag flag-18 flag-18-ee et-ee"></i>
#                 Eesti
#             </a>
#         </li>
#
#         <li>
#             <a title="Português" class="language-item anchor" data-selenium="menu-language12">
#                 <i uiculture="pt-pt" data="12" class="flag flag-18 flag-18-pt pt-pt"></i>
#                 Português
#             </a>
#         </li>
#
#         <li>
#             <a title="Türkçe" class="language-item anchor" data-selenium="menu-language32">
#                 <i uiculture="tr-tr" data="32" class="flag flag-18 flag-18-tr tr-tr"></i>
#                 Türkçe
#             </a>
#         </li>
#
#         <li>
#             <a title="Українська" class="language-item anchor" data-selenium="menu-language50">
#                 <i uiculture="uk-ua" data="50" class="flag flag-18 flag-18-ua uk-ua"></i>
#                 Українська
#             </a>
#         </li>
#
#         <li>
#             <a title="Nederlands" class="language-item anchor" data-selenium="menu-language13">
#                 <i uiculture="nl-nl" data="13" class="flag flag-18 flag-18-nl nl-nl"></i>
#                 Nederlands
#             </a>
#         </li>
#
#         <li>
#             <a title="Català" class="language-item anchor" data-selenium="menu-language33">
#                 <i uiculture="ca-es" data="33" class="flag flag-18 flag-18-es ca-es ca-es"></i>
#                 Català
#             </a>
#         </li>
# </ul>
#         </div>
#     </div>
# </li>
#                 <li class="navbar-menu-item">
#                     <a data-text="新臺幣" data-id="28" data-toggle="dropdown" title="TWD" id="currency" class="currency anchor" data-selenium="currency">TWD</a>
#
#     <div id="currencies-panel" class="currencies" data-selenium="currencies-panel" style="display: none;">
#         <div id="price-view">
#         </div>
#         <div class="" id="suggested-currency" style="display: block;">
#             <span class="section">建議貨幣</span>
#             <ul class="currencies-list">
#
#         <li data-id="28">
#             <a title="新臺幣" class="currency-item anchor" data-selenium="currency-code">
#                 <div class="currency-item-def" data-selenium="currency-item">
#                     <span>TWD</span>
#                 </div>
#                 <div class="title">
#                     <span>新臺幣</span>
#                 </div>
#             </a>
#         </li>
#  </ul>
#         </div>
#         <div class="" id="top-currencies" data-selenium="top-currencies" style="display: block;">
#             <span class="section">熱門貨幣</span>
#             <ul class="currencies-list">
#
#         <li data-id="3">
#             <a title="港幣" class="currency-item anchor" data-selenium="currency-code">
#                 <div class="currency-item-def" data-selenium="currency-item">
#                     <span>HKD</span>
#                 </div>
#                 <div class="title">
#                     <span>港幣</span>
#                 </div>
#             </a>
#         </li>
#
#         <li data-id="28">
#             <a title="新臺幣" class="currency-item anchor" data-selenium="currency-code">
#                 <div class="currency-item-def" data-selenium="currency-item">
#                     <span>TWD</span>
#                 </div>
#                 <div class="title">
#                     <span>新臺幣</span>
#                 </div>
#             </a>
#         </li>
#
#         <li data-id="7">
#             <a title="美元" class="currency-item anchor" data-selenium="currency-code">
#                 <div class="currency-item-def" data-selenium="currency-item">
#                     <span>USD</span>
#                 </div>
#                 <div class="title">
#                     <span>美元</span>
#                 </div>
#             </a>
#         </li>
#  </ul>
#         </div>
#         <div data-selenium="all-currencies" class="" id="all-currencies" style="display: block;">
#             <span class="section">全部貨幣</span>
#             <ul data-selenium="currencies-list" class="currencies-list">
#
#         <li data-id="13">
#             <a title=" 加拿大元" class="currency-item anchor" data-selenium="currency-code">
#                 <div class="currency-item-def" data-selenium="currency-item">
#                     <span>CAD</span>
#                 </div>
#                 <div class="title">
#                     <span> 加拿大元</span>
#                 </div>
#             </a>
#         </li>
#
#         <li data-id="35">
#             <a title="阿曼里亞爾" class="currency-item anchor" data-selenium="currency-code">
#                 <div class="currency-item-def" data-selenium="currency-item">
#                     <span>OMR</span>
#                 </div>
#                 <div class="title">
#                     <span>阿曼里亞爾</span>
#                 </div>
#             </a>
#         </li>
#
#         <li data-id="22">
#             <a title="捷克克朗 " class="currency-item anchor" data-selenium="currency-code">
#                 <div class="currency-item-def" data-selenium="currency-item">
#                     <span>CZK</span>
#                 </div>
#                 <div class="title">
#                     <span>捷克克朗 </span>
#                 </div>
#             </a>
#         </li>
#
#         <li data-id="15">
#             <a title="人民幣" class="currency-item anchor" data-selenium="currency-code">
#                 <div class="currency-item-def" data-selenium="currency-item">
#                     <span>CNY</span>
#                 </div>
#                 <div class="title">
#                     <span>人民幣</span>
#                 </div>
#             </a>
#         </li>
#
#         <li data-id="14">
#             <a title="阿聯迪爾汗" class="currency-item anchor" data-selenium="currency-code">
#                 <div class="currency-item-def" data-selenium="currency-item">
#                     <span>AED</span>
#                 </div>
#                 <div class="title">
#                     <span>阿聯迪爾汗</span>
#                 </div>
#             </a>
#         </li>
#
#         <li data-id="36">
#             <a title="斐濟元" class="currency-item anchor" data-selenium="currency-code">
#                 <div class="currency-item-def" data-selenium="currency-item">
#                     <span>FJD</span>
#                 </div>
#                 <div class="title">
#                     <span>斐濟元</span>
#                 </div>
#             </a>
#         </li>
#
#         <li data-id="20">
#             <a title="丹麥克朗" class="currency-item anchor" data-selenium="currency-code">
#                 <div class="currency-item-def" data-selenium="currency-item">
#                     <span>DKK</span>
#                 </div>
#                 <div class="title">
#                     <span>丹麥克朗</span>
#                 </div>
#             </a>
#         </li>
#
#         <li data-id="152">
#             <a title="俄羅斯盧布" class="currency-item anchor" data-selenium="currency-code">
#                 <div class="currency-item-def" data-selenium="currency-item">
#                     <span>RUB</span>
#                 </div>
#                 <div class="title">
#                     <span>俄羅斯盧布</span>
#                 </div>
#             </a>
#         </li>
#
#         <li data-id="165">
#             <a title="斯里蘭卡盧比" class="currency-item anchor" data-selenium="currency-code">
#                 <div class="currency-item-def" data-selenium="currency-item">
#                     <span>LKR</span>
#                 </div>
#                 <div class="title">
#                     <span>斯里蘭卡盧比</span>
#                 </div>
#             </a>
#         </li>
#
#         <li data-id="62">
#             <a title="太平洋法郎" class="currency-item anchor" data-selenium="currency-code">
#                 <div class="currency-item-def" data-selenium="currency-item">
#                     <span>XPF</span>
#                 </div>
#                 <div class="title">
#                     <span>太平洋法郎</span>
#                 </div>
#             </a>
#         </li>
#
#         <li data-id="55">
# ...
#           <li><a title="德國飯店" href="country/germany.html">德國住宿</a></li>
#           <li><a title="英國飯店" href="country/united-kingdom.html">英國住宿</a></li>
#           <li><a title="義大利飯店" href="country/italy.html">義大利住宿</a></li>
#            <li><a title="柬埔寨飯店" href="country/cambodia.html">柬埔寨住宿</a></li>
#         </ul></td><td><ul class="xslgray tex_left">
#       <li class="slgraybold"><a title="海島假期">海島假期</a></li>
#       <li><a title="馬爾地夫飯店" href="country/maldives.html">馬爾地夫住宿</a></li>
#         <li><a title="關島飯店" href="country/guam.html">關島住宿</a></li>
#       <li><a title="沖繩飯店" href="city/okinawa-jp.html">沖繩住宿</a></li>
#       <li><a title="峇里島飯店" href="city/bali-id.html">峇里島住宿</a></li>
#       <li><a title="亞庇飯店" href="city/kota-kinabalu-my.html">亞庇住宿</a></li>
#         <li><a title="普吉島飯店" href="city/phuket-th.html">普吉島住宿</a></li>
#           <li><a title="長灘島飯店" href="city/boracay-island-ph.html">長灘島住宿</a></li>
#           <li><a title="蘇梅島飯店" href="city/samui-th.html">蘇梅島住宿</a></li>
#       <li><a title="沙美島飯店" href="city/koh-samet-th.html">沙美島住宿</a></li>
#       <li><a title="薄荷島飯店" href="city/bohol-ph.html">薄荷島住宿</a></li>
#       <li><a title="龜島飯店" href="city/koh-tao-th.html">龜島住宿</a></li>
#         <li><a title="夏威夷飯店" href="region/hawaii-state-us.html">夏威夷住宿</a></li>
#           <li><a title="麗貝島飯店" href="city/koh-lipe-th.html">麗貝島住宿</a></li>
#            <li><a title="PP島飯店" href="city/koh-phi-phi-th.html">PP島住宿</a></li>
#           <li><a title="喀比飯店" href="city/krabi-th.html">喀比住宿</a></li>
#            <li><a title="民丹島飯店" href="city/bintan-island-id.html">民丹島住宿</a></li>
#             <li><a title="宿霧飯店" href="city/cebu-ph.html">宿霧住宿</a></li>
#             <li><a title="濟州島飯店" href="city/jeju-island-kr.html">濟州島住宿</a></li>
#
#     </ul></td>
#     <td><ul class="xslgray tex_left">
#        <li class="slgraybold"><a title="超人氣城市">超人氣城市</a></li>
#        <li><a title="香港飯店" href="city/hong-kong-hk.html">香港住宿</a></li>
#       <li><a title="東京飯店" href="city/tokyo-jp.html">東京住宿</a></li>
#       <li><a title="大阪飯店" href="city/osaka-jp.html">大阪住宿</a></li>
#       <li><a title="首爾飯店" href="city/seoul-kr.html">首爾住宿</a></li>
#       <li><a title="曼谷飯店" href="city/bangkok-th.html">曼谷住宿</a></li>
#            <li><a title="京都飯店" href="city/kyoto-jp.html">京都住宿</a></li>
#       <li><a title="新加坡飯店" href="city/singapore-sg.html">新加坡住宿</a></li>
#       <li><a title="澳門飯店" href="city/macau-mo.html">澳門住宿</a></li>
#       <li><a title="上海飯店" href="city/shanghai-cn.html">上海住宿</a></li>
#       <li><a title="深圳住宿" href="city/shenzhen-cn.html">深圳酒店</a></li>
#         <li><a title="北京飯店" href="city/beijing-cn.html">北京住宿</a></li>
#         <li><a title="廣州飯店" href="city/guangzhou-cn.html">廣州住宿</a></li>
#         <li><a title="福岡飯店" href="city/fukuoka-jp.html">福岡住宿</a></li>
#         <li><a title="吉隆坡飯店" href="city/kuala-lumpur-my.html">吉隆坡住宿</a></li>
#          <li><a title="札幌飯店" href="city/sapporo-jp.html">札幌住宿</a></li>
#          <li><a title="芭達雅飯店" href="city/pattaya-th.html">芭達雅住宿</a></li>
#         <li><a title="清邁飯店" href="city/chiang-mai-th.html">清邁住宿</a></li>
#             <li><a title="胡志明飯店" href="city/ho-chi-minh-city-vn.html">胡志明住宿</a></li>
#       </ul>      </td>
#
#     <td><ul class="xslgray tex_left"><li><a title="廈門飯店" href="city/xiamen-cn.html">廈門住宿</a></li>
#       <li><a title="釜山飯店" href="city/busan-kr.html">釜山住宿</a></li>
#       <li><a title="珠海飯店" href="city/zhuhai-cn.html">珠海住宿</a></li>
#           <li><a title="名古屋飯店" href="city/nagoya-jp.html">名古屋住宿</a></li>
#         <li><a title="巴黎飯店" href="city/paris-fr.html">巴黎住宿</a></li>
#               <li><a title="箱根町飯店" href="city/hakone-jp.html">箱根町住宿</a></li>
#         <li><a title="倫敦飯店" href="city/london-gb.html">倫敦住宿</a></li>
#         <li><a title="華欣飯店" href="city/hua-hin-cha-am-th.html">華欣住宿</a></li>
#         <li><a title="富士山飯店" href="city/mount-fuji-jp.html">富士山住宿</a></li>
#         <li><a title="檳城飯店" href="city/penang-my.html">檳城住宿</a></li>
#         <li><a title="雪梨飯店" href="city/sydney-au.html">雪梨住宿</a></li>
#             <li><a title="馬尼拉飯店" href="city/manila-ph.html">馬尼拉住宿</a></li>
#         <li><a title="杭州飯店" href="city/hangzhou-cn.html">杭州住宿</a></li>
#         <li><a title="長野飯店" href="city/nagano-jp.html">長野住宿</a></li>
#         <li><a title="神戶飯店" href="city/kobe-jp.html">神戶住宿</a></li>
#       <li><a title="墨爾本飯店" href="city/melbourne-au.html">墨爾本住宿</a></li>
#       <li><a title="北海道飯店" href="region/hokkaido-prefecture-jp.html">北海道住宿</a></li>
#
#
#       </ul></td>
#     <td><ul class="xslgray tex_left">
#          <li class="slgraybold"><a title="國內訂房">國內訂房</a></li>
#       <li><a title="台北飯店" href="city/taipei-tw.html">台北住宿</a></li>
#       <li><a title="台中飯店" href="city/taichung-tw.html">台中住宿</a></li>
#       <li><a title="高雄飯店" href="city/kaohsiung-tw.html">高雄住宿</a></li>
#       <li><a title="桃園飯店" href="city/taoyuan-tw.html">桃園住宿</a></li>
#       <li><a title="嘉義飯店" href="city/chiayi-tw.html">嘉義住宿</a></li>
#       <li><a title="新竹飯店" href="city/hsinchu-tw.html">新竹住宿</a></li>
#       <li><a title="基隆飯店" href="region/keelung-province-tw.html">基隆住宿</a></li>
#       <li><a title="澎湖飯店" href="city/penghu-tw.html">澎湖住宿</a></li>
#       <li><a title="金門飯店" href="city/kinmen-tw.html">金門住宿</a></li>
#        <li><a title="彰化飯店" href="city/changhua-tw.html">彰化住宿</a></li>
#       <li><a title="苗栗飯店" href="city/miaoli-tw.html">苗栗住宿</a></li>
#        <li><a title="雲林飯店" href="city/yunlin-tw.html">雲林住宿</a></li>
#       <li><a title="花蓮住宿" href="city/hualien-tw.html">花蓮民宿</a></li>
#       <li><a title="台南住宿" href="city/tainan-tw.html">台南民宿</a></li>
#       <li><a title="南投住宿" href="city/nantou-tw.html">南投民宿</a></li>
#       <li><a title="宜蘭住宿" href="city/yilan-tw.html">宜蘭民宿</a></li>
#       <li><a title="台東住宿" href="city/taitung-tw.html">台東民宿</a></li>
#       <li><a title="屏東住宿" href="city/pingtung-tw.html">屏東民宿</a></li>
#       </ul></td>
#     <td><ul class="xslgray tex_left">
#       <li class="slgraybold"><a title="寶島景點">台灣熱門景點</a></li>
#       <li><a title="墾丁住宿" href="city/kenting-tw.html">墾丁民宿</a></li>
#       <li><a title="九份住宿" href="jiu-fen/maps/taipei-tw.html">九份民宿</a></li>
#       <li><a title="阿里山住宿" href="alishan-township/maps/chiayi-tw.html">阿里山民宿</a></li>
#       <li><a title="清境住宿" href="cingjing/maps/nantou-tw.html">清境民宿</a></li>
#       <li><a title="礁溪住宿" href="jiaoxi-township/maps/yilan-tw.html">礁溪民宿</a></li>
#       <li><a title="蘇澳住宿" href="hotels-near-su-au-cold-spring/attractions/yilan-tw.html">蘇澳民宿</a></li>
#       <li><a title="日月潭住宿" href="hotels-near-sun-moon-lake/attractions/nantou-tw.html">日月潭民宿</a></li>
#       <li><a title="烏來民宿" href="wulai-district/maps/taipei-tw.html">烏來住宿</a></li>
#       <li><a title="淡水住宿" href="tamsui-district/maps/taipei-tw.html">淡水民宿</a></li>
#       <li><a title=" 小琉球住宿" href="city/liuqiu-tw.html">小琉球民宿</a></li>
#       <li><a title="北投旅館" href="beitou-district/maps/taipei-tw.html">北投住宿</a></li>
#       <li><a title="西門町飯店" href="ximending/maps/taipei-tw.html">西門町住宿</a></li>
#       <li><a title="士林夜市飯店" href="hotels-near-shilin-night-market/attractions/taipei-tw.html">士林夜市住宿</a></li>
#       <li><a title="逢甲夜市飯店" href="hotels-near-fengchia-night-market/attractions/taichung-tw.html">逢甲夜市住宿</a></li>
#       <li><a title="師大夜市飯店" href="hotels-near-shida-night-market/attractions/taipei-tw.html">師大夜市住宿</a></li>
#       <li><a title="溪頭住宿" href="xitou/maps/nantou-tw.html">溪頭民宿</a></li>
#       <li><a title="太魯閣民宿" href="hotels-near-taroko-national-park/attractions/hualien-tw.html">太魯閣住宿</a></li>
#       <li><a title="奧萬大民宿" href="hotels-near-aowanda-national-forest-recreation-area/attractions/nantou-tw.html">奧萬大住宿</a></li></ul></td></tr></tbody></table>
#             </div>
#         </div>
#
#     <section data-selenium="footer-copyright-section" class="main-footer-bottom">
#         <div class="container-agoda">
#             <div class="row">
#                 <div class="col-xs-12">
#                     <p>
#                     版權所有©2005 – 2016, Agoda Company Pte. Ltd.保留所有權利
#                     </p>
#                     <p>
#                     Agoda.com隸屬於Priceline集團—線上旅遊業及相關服務的全球領導品牌。
#                     </p>
#                     <ul class="pg-brand-list">
#                         <li class="pg-brand-list-item"><i class="pg-brand pg-brand-01"></i></li>
#                         <li class="pg-brand-list-item"><i class="pg-brand pg-brand-02"></i></li>
#                         <li class="pg-brand-list-item"><i class="pg-brand pg-brand-03"></i></li>
#                         <li class="pg-brand-list-item"><i class="pg-brand pg-brand-04"></i></li>
#                         <li class="pg-brand-list-item"><i class="pg-brand pg-brand-05"></i></li>
#                         <li class="pg-brand-list-item"><i class="pg-brand pg-brand-06"></i></li>
#                     </ul>
#                 </div>
#             </div>
#         </div>
#     </section>
#
#     <section class="main-footer-system-env small">
#         <div class="container-agoda">
#             <div class="col-xs-12">
#                 <small>HK-AGWEB-2G07</small>
#             </div>
#         </div>
#     </section>
#
# </footer>
#
# <div class="hide" id="page-backdrop"></div>
#
#
#
#
#
#
#
#
#
#
#
# <script>
#     var agoda = agoda || {};
#     agoda.pageConfig = {
#         pageTypeId: 1,
#         origin: "TW",
#         cid: "-1",
#         htmlLanguage: "zh-tw"
#     };
# </script>
#
#
#
#
#     <script>
#         agoda.searchBoxConfig = {
#             autocompleteUrl: "/Search/Search/GetUnifiedSuggestResult/3/20/1/0/zh-tw",
#             userID: "a084d4d7-f152-4cfd-95e6-8ec92e340273",
#             defaultText: "",
#             defaultOccupancy: {
#                 adults: 2,
#                 children: 0,
#                 rooms: 1
#                 },
#             checkInDate: new Date(2016, 9 - 1, 3),
#             defaultCheckInDate: new Date(2016, 9 - 1, 3),
#
#             lengthOfStays: 1,
#
#             failsafeUrl: "/newsite/zh-tw/searchresult/Search",
#             targetSearchUrl: "",
#             languageId: 20,
#             rules: {
#                 textLengh: {
#                     min: 1,
#                     max: 1000
#                 },
#                 allowSearchYersterday: true
#             },
#             autoSuggestRequest: {
#                 all: 0,
#                 city: 0,
#                 area: 0,
#                 airport: 0,
#                 landmark: 0,
#                 hotel: 0
#             }
#         };
#     </script>
#
#
#     <script>
#
#         agoda.heroBanner = {
#             header1: '在 [ReplaceMe] 找好窩 走跳世界',
#             header2: '訂飯店、住Villa、找民宿 包山包海超過925,000+間國內外各類住宿！',
#             finalTerm: 'Agoda',
#             listOfTerms: '紐約(NY),巴塞隆納,曼谷',
#             replaceText: 'ReplaceMe',
#             hostedContent: '.hero-banner-hosted'
#         };
#
#         agoda.gaConfig = {
#
#             enabled: false,
#
#             source: "",
#             medium: "",
#             campaign: null,
#
#             continentName: null,
#             countryName: null,
#             cityName: null,
#
#             pageTypeId: 1,
#
#             propertyType: null,
#             hotelName: null,
#             rate: null,
#
#             virtualPath: "/NewSite/zh-tw/home/index",
#             machineName: "HK-AGWEB-2G07"
#         }
#
#
#             var widgetId = 'flight-widget2';
#             agoda.flightBanner = {
#                 widgetId: widgetId,
#                 languageCode: 'zh-tw',
#                 currencyCode: 'TWD',
#                 placement: '',
#
#                 cms: {
#                     pleaseEnterFromAirport:'請輸入「出發地」機場名稱或代碼。',
#                     pleaseEnterToAirport:  '請輸入「目的地」機場名稱或代碼。',
#                     pleaseEnterDepartDate: '請選擇「出發日期」。',
#                     pleaseEnterReturnDate: '請選擇「回程日期」。只需單程請選「單程機票」。'
#                 },
#
#                 // skip delay load script because we try to show the flight tab first
#                 skipGetScript: false,
#
#                 isV2S: true,
#                 isFlightTab: false,
#                 isSendMeasurement: false,
#                 isDebugMessage: false
#             };
#
#
#         agoda.initPage = function () {
#             // need to be call after document ready to ensure that all javascript(agoda.experiment script) have been loaded
#             var list = [];
#
#                 list = [];
#
#
#             var param = {
#                 experimentList: list
#             };
#             agoda.experiment.init(param);
#
#                  urgencyMessage.initHome();
#         }
#
#     </script>
#
#
#
#             <!-- Tealium Script -->
#
# <script type="text/javascript">
#     var rtag_hotelid = 0;
#     var rtag_allhotelids = [];
#     var rtag_hotelid1 = 0;
#     var rtag_hotelid2 = 0;
#     var rtag_hotelid3 = 0;
#     var rtag_countryid = 0;
#     var rtag_cityid = 0;
#     var rtag_cityname = "";
#     var rtag_checkin = "";
#     var rtag_checkout = "";
#     var rtag_cid = -1;
#     var rtag_sid = 0;
#     var rtag_pagetypeid = 1;
#     var rtag_langid = 20;
#     var rtag_adult = 0;
#     var rtag_child = 0;
#     var rtag_star_rating = 0;
#     var rtag_is_dev = false;
#     var rtag_is_qa = false;
#     var rtag_is_live = true;
#     var rtag_devicetype = "d";
#     var rtag_ue = "";
#     var rtag_country_origin = "TW";
#
#     var rtag_exp_rmkt_1 = "B";
#     var rtag_exp_rmkt_2 = "Z";
#     var rtag_exp_rmkt_3 = "Z";
#     var rtag_exp_rmkt_4 = "Z";
#     var rtag_exp_rmkt_5 = "A";
#
# </script>
#
# <script type="text/javascript">
#     var tealiumServerEnv = "";
#         tealiumServerEnv = "prod";
#
#     var utag_data = {
#
#     };
#
#     (function(a, b, c, d) {
#         a = '//tags.tiqcdn.com/utag/agoda/main/' + tealiumServerEnv + '/utag.js';
#         b = document;
#         c = 'script';
#         d = b.createElement(c);
#         d.src = a;
#         d.type = 'text/java' + c;
#         d.async = true;
#         a = b.getElementsByTagName(c)[0];
#         a.parentNode.insertBefore(d, a);
#     })();
# </script>
#
# <script>
#
#
#     window.currencyUrl =
#     {
#         get: '/api/zh-tw/Main/GetCurrencyList?HotelId=0&amp;amp;countryId=0',
#         set: '/api/zh-tw/Main/SetSelectedCurency'
#     };
#     if (window.currencyUrl.get.indexOf("&amp;amp;") &gt; -1)
#         window.currencyUrl.get = window.currencyUrl.get.replace("&amp;amp;", "&amp;");
#
#     if (true) {
#         window.currencyUrl.get = window.currencyUrl.get.replace("countryId=0", "countryId=" + (window.countryId || null));
#     }
#
#
#     window.languageUrl =
#     {
#         get: '/api/zh-tw/Main/GetLanguages',
#         set: '/api/zh-tw/Main/SetSelectedLanguage'
#     };
#
#
#     window.eventLogURL = '/api/zh-tw/Main/LogEventMessage';
#     var agoda = agoda || { };
#     agoda.RewardsMember = {IsLogin : false};
#
#
# </script>
#
#
#
#
#
# <!--_RUMAgoda-->
# <script id="RUMAgoda" type="text/javascript">
#     agoda = agoda || {};
#     agoda.rumpagetype = 'newhome';
#
# </script>
# <!--end of _RUMAgoda-->
#
#
#
#
# <script type="text/javascript">window.ExperimentManager.mapping.push("MIN-5907","SEARCH-423","LOGIN-333","HALO-4256","TEXT-749-1","SEARCH-1237","HALO-4150","SEARCH-1181","TEXT-686","HALO-4362","HALO-4157","TEXT-919","HALO-4179-KILLSWITCH","HALO-4404");</script><script crossorigin="anonymous" src="https://cdn6.agoda.net/js/mvc/assets/home/index/all-28d62223b0.js" async=""></script>
#
#
#
#
# <div class="ui-datepicker ui-widget ui-widget-content ui-helper-clearfix ui-corner-all" id="ui-datepicker-div"></div><script type="text/javascript" async="" src="https://nebula-cdn.kampyle.com/wu/71154/onsite/generic1471451420162.js"></script><span><div style="z-index: 2147483000; border: 0px none; position: fixed; display: block; width: 0px; height: 0px;" id="KampyleAnimationContainer"></div></span><script type="text/javascript" async="" src="//screencapture.kampyle.com/screenApi/load/0d9bccf0-07c5-4694-abf9-9f4bcf1d1ec2.js"></script><span id="kampyleButtonContainer"><div tabindex="0" style="z-index: 99999990 !important;position: fixed !important;cursor: pointer !important;bottom:0;left:0;" class=" noOutline " id="nebula_div_btn"><img src="https://nebula-cdn.kampyle.com/wu/71154/resources/image/1464614402627_1x1.png" alt="Feedback" /></div></span><iframe style="display: none;"></iframe></body></html>

# %%
soup = BeautifulSoup(html_source, 'lxml')
soup.find_all('h3', class_="hotel-name")
# Out:
# []

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

driver = webdriver.Firefox()
driver.get("http://www.python.org")
assert "Python" in driver.title
elem = driver.find_element_by_name("q")
elem.clear()
elem.send_keys("pycon")
elem.send_keys(Keys.RETURN)
html_source = driver.page_source
print html_source
driver.close()
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>   <html class="no-js ie6 lt-ie7 lt-ie8 lt-ie9">   <![endif]-->
# <!--[if IE 7]>      <html class="no-js ie7 lt-ie8 lt-ie9">          <![endif]-->
# <!--[if IE 8]>      <html class="no-js ie8 lt-ie9">                 <![endif]-->
# <!--[if gt IE 8]><!-->
# <html xmlns="http://www.w3.org/1999/xhtml" lang="en" dir="ltr" class=" js no-touch geolocation fontface generatedcontent svg formvalidation placeholder boxsizing" style=""><!--<![endif]--><head>
#     <meta charset="utf-8" />
#     <meta content="IE=edge" http-equiv="X-UA-Compatible" />
#
#     <link href="//ajax.googleapis.com/ajax/libs/jquery/1.8.2/jquery.min.js" rel="prefetch" />
#
#     <meta content="Python.org" name="application-name" />
#     <meta content="The official home of the Python Programming Language" name="msapplication-tooltip" />
#     <meta content="Python.org" name="apple-mobile-web-app-title" />
#     <meta content="yes" name="apple-mobile-web-app-capable" />
#     <meta content="black" name="apple-mobile-web-app-status-bar-style" />
#
#     <meta content="width=device-width, initial-scale=1.0" name="viewport" />
#     <meta content="True" name="HandheldFriendly" />
#     <meta content="telephone=no" name="format-detection" />
#     <meta content="on" http-equiv="cleartype" />
#     <meta content="false" http-equiv="imagetoolbar" />
#
#     <script src="/static/js/libs/modernizr.js"></script>
#
#     <link title="default" type="text/css" rel="stylesheet" href="/static/stylesheets/style.css" />
#     <link media="not print, braille, embossed, speech, tty" type="text/css" rel="stylesheet" href="/static/stylesheets/mq.css" />
#
#
#     <!--[if (lte IE 8)&(!IEMobile)]>
#     <link href="/static/stylesheets/no-mq.css" rel="stylesheet" type="text/css" media="screen" />
#
#
#     <![endif]-->
#
#
#     <link href="/static/favicon.ico" type="image/x-icon" rel="icon" />
#     <link href="/static/apple-touch-icon-144x144-precomposed.png" sizes="144x144" rel="apple-touch-icon-precomposed" />
#     <link href="/static/apple-touch-icon-114x114-precomposed.png" sizes="114x114" rel="apple-touch-icon-precomposed" />
#     <link href="/static/apple-touch-icon-72x72-precomposed.png" sizes="72x72" rel="apple-touch-icon-precomposed" />
#     <link href="/static/apple-touch-icon-precomposed.png" rel="apple-touch-icon-precomposed" />
#     <link href="/static/apple-touch-icon-precomposed.png" rel="apple-touch-icon" />
#
#
#     <meta content="/static/metro-icon-144x144-precomposed.png" name="msapplication-TileImage" /><!-- white shape -->
#     <meta content="#3673a5" name="msapplication-TileColor" /><!-- python blue -->
#     <meta content="#3673a5" name="msapplication-navbutton-color" />
#
#     <title>Welcome to Python.org</title>
#
#     <meta content="The official home of the Python Programming Language" name="description" />
#     <meta content="Python programming language object oriented web free open source software license documentation download community" name="keywords" />
#
#
#     <meta content="website" property="og:type" />
#     <meta content="Python.org" property="og:site_name" />
#     <meta content="Welcome to Python.org" property="og:title" />
#     <meta content="The official home of the Python Programming Language" property="og:description" />
#
#     <meta content="https://www.python.org/static/opengraph-icon-200x200.png" property="og:image" />
#     <meta content="https://www.python.org/static/opengraph-icon-200x200.png" property="og:image:secure_url" />
#
#     <meta content="https://www.python.org/search/?q=pycon&amp;submit=" property="og:url" />
#
#     <link href="/static/humans.txt" rel="author" />
#
#
#
#
#     <script type="application/ld+json">
#      {
#        "@context": "http://schema.org",
#        "@type": "WebSite",
#        "url": "https://www.python.org/",
#        "potentialAction": {
#          "@type": "SearchAction",
#          "target": "https://www.python.org/search/?q={search_term_string}",
#          "query-input": "required name=search_term_string"
#        }
#      }
#     </script>
#
#
#     <script type="text/javascript">
#     var _gaq = _gaq || [];
#     _gaq.push(['_setAccount', 'UA-39055973-1']);
#     _gaq.push(['_trackPageview']);
#
#     (function() {
#         var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#         ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#         var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#     })();
#     </script></head></html>

# %%
# Transform

# %%
mydict = {
    'product_name': 'Apple Macbook Pro',
    'price': '$2,345,000',
    'start_data': '2016年01月02日',
    'end_data': '2016年01月30日',
    'mobile': '0932-124-483',
    'phone': '(02)2341-2348'
}

# %%
# datetime
# re
# string built-in methods
