# %%
URL = "https://world.taobao.com/search/search.htm?cat=50043774&_ksTS=1472519583989_41&spm=a21bp.7806943.banner_TW_cat.913.Eq8DrV&_input_charset=utf-8&navigator=all&json=on&cna=pspLEC6I%20TYCAYxz7CfV%20WXk&callback=__jsonp_cb&abtest=_AB-LR517-LR854-LR895-PR517-PR854-PR895"

# %%
import requests as r
from bs4 import BeautifulSoup
from datetime import datetime
import MySQLdb

# %%
res = r.get(URL)

# %%
res.status_code
# Out:
# 200

# %%
res.headers
# Out:
# {'Content-Language': 'zh-CN', 'Content-Encoding': 'gzip', 'Transfer-Encoding': 'chunked', 'Set-Cookie': 'v=0; Domain=.taobao.com; Path=/, cookie2=1ca268b41ad6f1939958544891488eb1;Domain=.taobao.com;Path=/;HttpOnly, t=88c65a0601957448aecf757d65b7c702; Domain=.taobao.com; Expires=Fri, 09-Dec-2016 06:29:08 GMT; Path=/, _tb_token_=USu1Hevvgsp; Domain=.taobao.com; Path=/, thw=tw; Path=/; Domain=.taobao.com; Expires=Sun, 10-Sep-17 06:29:08 GMT;', 'Strict-Transport-Security': 'max-age=31536000', 'Vary': 'Accept-Encoding, Accept-Encoding, Accept-Encoding', 'S': 'STATUS_NOT_EXISTED', 'Server': 'Tengine', 'Connection': 'keep-alive', 'Date': 'Sat, 10 Sep 2016 06:29:08 GMT', 'P3P': "CP='CURa ADMa DEVa PSAo PSDo OUR BUS UNI PUR INT DEM STA PRE COM NAV OTC NOI DSP COR'", 'Content-Type': 'text/html;charset=GBK', 'Timing-Allow-Origin': '*'}

# %%
res.text
# Out:
# u'\n<!DOCTYPE html>\n<html>\n<head>\n<meta charset="utf-8"/>\n<meta name="aplus-rate-ahot" content="0.5"/>\n<meta name="aplus-rate-ahot-res" content="0.5"/>\n<link rel="stylesheet" href="//g.alicdn.com//sea/sitenav-global/0.6.0/global-min.css">\n<script src="//g.alicdn.com/kissy/k/1.4.16/seed-min.js"></script>\n<script src="//g.alicdn.com//sea/sitenav-global/0.6.0/global-min.js" charset="UTF-8"></script>\n<script src="//g.alicdn.com/kg/kmd-adapter/0.0.6/index.js"></script>\n<script charset="UTF-8" src="//g.alicdn.com//cm/log/log.js" crossorigin></script>\n<script type="text/javascript">\r\nwindow.g_config = window.g_config || {};\r\ng_config.appId = 2;\r\ng_config.toolbar = false;\r\n\r\nwindow.__WPO && window.__WPO.setConfig({\r\n    sample: 10, // \u62bd\u6837\u7387\uff0c100 = 1%\uff0c1 = 100%\uff0c\u9ed8\u8ba4100\r\n    spmId: \'a312a.7700714\'\r\n});\r\nwindow.i18n= {"SuZhou":"\u82cf\u5dde","HeNan":"\u6cb3\u5357","FuZhou":"\u798f\u5dde","item_desc":"\u63cf\u8ff0","Xian":"\u897f\u5b89","triple_tips":"\u5047\u4e00\u8d54\u4e09","total_page_tips":"\u5171 xx \u9875","sorry_nofind_tips":"\u62b1\u6b49\uff01\u6ca1\u6709\u627e\u5230\u4e0e","same_tips":"xx \u4ef6\u540c\u6b3e","item_send_time":"\u5356\u5b
":"\u540c\u6b3e","comp_sort_tips":"\u7efc\u5408\u6392\u5e8f","creditcard_tips":"\u4fe1\u7528\u5361","auto_cat_show":"\u663e\u793a\u7b5b\u9009\u533a","quality_seller_tips":"\u5356\u5bb6\u627f\u8bfa\u6b63\u54c1\u4fdd\u969c","tmall_hk_tips":"\u5929\u732b\u56fd\u9645","overview_again":"\u770b\u4e86\u8fd9\u4e2a\u7684\u8fd8\u770b\u4e86","empty_head_tips":"\u65e0\u6cd5\u663e\u793a","HongKong":"\u9999\u6e2f","HuBei":"\u6e56\u5317","mysearch_tab_favorites":"\u6536\u85cf\u8fc7\u7684\u5e97","screen_area_ti ...

# %%
# Let's try using Selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

driver = webdriver.Firefox()
driver.get(URL)
# elem = driver.find_element_by_name("q")
# elem.clear()
# elem.send_keys("selenium")
# elem.send_keys(Keys.RETURN)
html_source = driver.page_source
print html_source
driver.close()
# Out:
# ---------------------------------------------------------------------------
# BadStatusLine                             Traceback (most recent call last)
# <ipython-input-8-eea0ab591291> in <module>()
#       4
#       5 driver = webdriver.Firefox()
# ----> 6 driver.get(URL)
#       7 # elem = driver.find_element_by_name("q")
#       8 # elem.clear()
#
# E:\Anaconda2\lib\site-packages\selenium\webdriver\remote\webdriver.pyc in get(self, url)
#     246         Loads a web page in the current browser session.
#     247         """
# --> 248         self.execute(Command.GET, {'url': url})
#     249
#     250     @property
#
# E:\Anaconda2\lib\site-packages\selenium\webdriver\remote\webdriver.pyc in execute(self, driver_command, params)
#     232
#     233         params = self._wrap_value(params)
# --> 234         response = self.command_executor.execute(driver_command, params)
#     235         if response:
#     236             self.error_handler.check_response(response)
#
# E:\Anaconda2\lib\site-packages\selenium\webdriver\remote\remote_connection.pyc in execute(self, command, params)
#     399         path = string.Template(command_info[1]).substitute(params)
#     400         url = '%s%s' % (self._url, path)
# --> 401         return self._request(command_info[0], url, body=data)
#     402
#     403     def _request(self, method, url, body=None):
#
# E:\Anaconda2\lib\site-packages\selenium\webdriver\remote\remote_connection.pyc in _request(self, method, url, body)
#     431             try:
#     432                 self._conn.request(method, parsed_url.path, body, headers)
# --> 433                 resp = self._conn.getresponse()
#     434             except (httplib.HTTPException, socket.error):
#     435                 self._conn.close()
#
# E:\Anaconda2\lib\httplib.pyc in getresponse(self, buffering)
#    1134
#    1135         try:
# -> 1136             response.begin()
#    1137             assert response.will_close != _UNKNOWN
#    1138             self.__state = _CS_IDLE
#
# E:\Anaconda2\lib\httplib.pyc in begin(self)
#     451         # read until we get a non-100 response
#     452         while True:
# --> 453             version, status, reason = self._read_status()
#     454             if status != CONTINUE:
#     455                 break
#
# E:\Anaconda2\lib\httplib.pyc in _read_status(self)
#     415             # Presumably, the server closed the connection before
#     416             # sending a valid response.
# --> 417             raise BadStatusLine(line)
#     418         try:
#     419             [version, status, reason] = line.split(None, 2)
#
# BadStatusLine: ''

# %%
soup = BeautifulSoup(html_source, 'lxml')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-7be0ab224dff> in <module>()
# ----> 1 soup = BeautifulSoup(html_source, 'lxml')
#
# NameError: name 'html_source' is not defined

# %%
# Item img
soup.find_all('li', class_="item")[0].find('img')['src']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-b3aada7363cf> in <module>()
#       1 # Item img
# ----> 2 soup.find_all('li', class_="item")[0].find('img')['src']
#
# NameError: name 'soup' is not defined

# %%
# Item price in RMB
soup.find_all('li', class_="item")[0].find('strong').text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-5cd0c74effea> in <module>()
#       1 # Item price in RMB
# ----> 2 soup.find_all('li', class_="item")[0].find('strong').text
#
# NameError: name 'soup' is not defined

# %%
# Item title
soup.find_all('li', class_="item")[0].find(class_='title').text.strip()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-3ca542bb3318> in <module>()
#       1 # Item title
# ----> 2 soup.find_all('li', class_="item")[0].find(class_='title').text.strip()
#
# NameError: name 'soup' is not defined

# %%
# Item URL
soup.find_all('li', class_="item")[0].find(class_='title').a['href']
#soup.find_all('li', class_="item")[0].find(class_='title').find('a')['href']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-9ba2b8e1e398> in <module>()
#       1 # Item URL
# ----> 2 soup.find_all('li', class_="item")[0].find(class_='title').a['href']
#       3 #soup.find_all('li', class_="item")[0].find(class_='title').find('a')['href']
#
# NameError: name 'soup' is not defined

# %%
# Seller id
soup.find_all('li', class_="item")[0].find('a', class_='nick').text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-c258b7de463a> in <module>()
#       1 # Seller id
# ----> 2 soup.find_all('li', class_="item")[0].find('a', class_='nick').text
#
# NameError: name 'soup' is not defined

# %%
len(soup.find_all('li', class_="item"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-fb3b7b56da6e> in <module>()
# ----> 1 len(soup.find_all('li', class_="item"))
#
# NameError: name 'soup' is not defined

# %%
items = soup.find_all('li', class_="item") # list of items
# List of items scraped from website
items_list = []
for item in items:
    # Define a new empty dictionary for each item
    item_dict = {}
    print "="*5 + item.find(class_='title').text.strip() + "="*5
    item_dict['title'] = item.find(class_='title').text.strip()
    item_dict['item_url'] = item.find(class_='title').a['href']
    item_dict['price'] = item.find('strong').text
    item_dict['img_url'] = item.find('img')['src']
    items_list.append(item_dict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-3b22cb60cc4c> in <module>()
# ----> 1 items = soup.find_all('li', class_="item") # list of items
#       2 # List of items scraped from website
#       3 items_list = []
#       4 for item in items:
#       5     # Define a new empty dictionary for each item
#
# NameError: name 'soup' is not defined

# %%
items_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-dcbf693aba7b> in <module>()
# ----> 1 items_list
#
# NameError: name 'items_list' is not defined

# %%
# from selenium.webdriver.support.ui import WebDriverWait
# from selenium.webdriver.support import expected_conditions
# from selenium.webdriver.common.by import By

# driver = webdriver.Firefox()
# driver.get(URL)


# # Wait ultil some element with class name "hotel-name" appear on the page
# elem_present = expected_conditions.presence_of_element_located((By.CLASS_NAME, 'nick'))
# WebDriverWait(driver, 10).until(elem_present)

# for x in range(0,9):
#     print "start finding next button"
#     elem = driver.find_element_by_css_selector('a.J_Ajax:nth-child(8)')
#     print "foudn next button"
#     driver.execute_script("return window.scrollBy(0, 7500)")
#     #driver.execute_script("return arguments[0].scrollIntoView();", elem)
#     elem.click()
    

# print driver.page_source

# %% [markdown]
# # MySQL

# %%
# conda install mysql-python
# 安裝完後，重新啟動Jupyter Notebook

# %%
import MySQLdb

# %%
db = MySQLdb.connect("localhost", "ian", "password", "testdb")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-21-737367bcf29d> in <module>()
# ----> 1 db = MySQLdb.connect("localhost", "ian", "password", "testdb")
#
# E:\Anaconda2\lib\site-packages\MySQLdb\__init__.pyc in Connect(*args, **kwargs)
#      79     """Factory function for connections.Connection."""
#      80     from MySQLdb.connections import Connection
# ---> 81     return Connection(*args, **kwargs)
#      82
#      83 connect = Connection = Connect
#
# E:\Anaconda2\lib\site-packages\MySQLdb\connections.pyc in __init__(self, *args, **kwargs)
#     191         autocommit = kwargs2.pop('autocommit', False)
#     192
# --> 193         super(Connection, self).__init__(*args, **kwargs2)
#     194         self.cursorclass = cursorclass
#     195         self.encoders = dict([ (k, v) for k, v in conv.items()
#
# OperationalError: (1045, "Access denied for user 'ian'@'localhost' (using password: YES)")

# %%
type(db)

# %%
cursor = db.cursor()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-e861273d6579> in <module>()
# ----> 1 cursor = db.cursor()
#
# NameError: name 'db' is not defined

# %%
type(cursor)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-ea64deaf370c> in <module>()
# ----> 1 type(cursor)
#
# NameError: name 'cursor' is not defined

# %%
sql = """CREATE TABLE CONTACTS (
         NAME VARCHAR(255) NOT NULL,
         JOB  VARCHAR(255),
         HOBBY VARCHAR(255))"""

# %%
cursor.execute(sql)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-3e948e25d2e0> in <module>()
# ----> 1 cursor.execute(sql)
#
# NameError: name 'cursor' is not defined

# %%
db.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-de8b2821562c> in <module>()
# ----> 1 db.close()
#
# NameError: name 'db' is not defined

# %%
sql = """INSERT INTO contacts ( hobby, job, name) VALUES ("ian", "engineer", "running")"""

# %%
db = MySQLdb.connect("localhost", "ian", "password", "testdb")
cursor = db.cursor()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-28-cd5107623bd9> in <module>()
# ----> 1 db = MySQLdb.connect("localhost", "ian", "password", "testdb")
#       2 cursor = db.cursor()
#
# E:\Anaconda2\lib\site-packages\MySQLdb\__init__.pyc in Connect(*args, **kwargs)
#      79     """Factory function for connections.Connection."""
#      80     from MySQLdb.connections import Connection
# ---> 81     return Connection(*args, **kwargs)
#      82
#      83 connect = Connection = Connect
#
# E:\Anaconda2\lib\site-packages\MySQLdb\connections.pyc in __init__(self, *args, **kwargs)
#     191         autocommit = kwargs2.pop('autocommit', False)
#     192
# --> 193         super(Connection, self).__init__(*args, **kwargs2)
#     194         self.cursorclass = cursorclass
#     195         self.encoders = dict([ (k, v) for k, v in conv.items()
#
# OperationalError: (1045, "Access denied for user 'ian'@'localhost' (using password: YES)")

# %%
cursor.execute(sql)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-3e948e25d2e0> in <module>()
# ----> 1 cursor.execute(sql)
#
# NameError: name 'cursor' is not defined

# %%
db.commit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-1411d94ebbaf> in <module>()
# ----> 1 db.commit()
#
# NameError: name 'db' is not defined

# %%
db.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-de8b2821562c> in <module>()
# ----> 1 db.close()
#
# NameError: name 'db' is not defined

# %%
# Clean up...

# %%
db = MySQLdb.connect("localhost", "ian", "password", "testdb")
cursor = db.cursor()

sql = """INSERT INTO contacts ( name, job, hobby) VALUES ("john", "engineer", "running")"""
cursor.execute(sql)
db.commit()

db.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-33-90f170017f64> in <module>()
# ----> 1 db = MySQLdb.connect("localhost", "ian", "password", "testdb")
#       2 cursor = db.cursor()
#       3
#       4 sql = """INSERT INTO contacts ( name, job, hobby) VALUES ("john", "engineer", "running")"""
#       5 cursor.execute(sql)
#
# E:\Anaconda2\lib\site-packages\MySQLdb\__init__.pyc in Connect(*args, **kwargs)
#      79     """Factory function for connections.Connection."""
#      80     from MySQLdb.connections import Connection
# ---> 81     return Connection(*args, **kwargs)
#      82
#      83 connect = Connection = Connect
#
# E:\Anaconda2\lib\site-packages\MySQLdb\connections.pyc in __init__(self, *args, **kwargs)
#     191         autocommit = kwargs2.pop('autocommit', False)
#     192
# --> 193         super(Connection, self).__init__(*args, **kwargs2)
#     194         self.cursorclass = cursorclass
#     195         self.encoders = dict([ (k, v) for k, v in conv.items()
#
# OperationalError: (1045, "Access denied for user 'ian'@'localhost' (using password: YES)")

# %%
# Using string formatting to construct SQL statement

# %%
db = MySQLdb.connect("localhost", "ian", "password", "testdb")
cursor = db.cursor()

name = 'ian'
job = 'developer'
hobby = 'cycling'

sql = """INSERT INTO contacts ( name, job, hobby) VALUES ("{}", "{}", "{}")""".format(name, job, hobby)
cursor.execute(sql)
db.commit()

db.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-35-85bfdd258d40> in <module>()
# ----> 1 db = MySQLdb.connect("localhost", "ian", "password", "testdb")
#       2 cursor = db.cursor()
#       3
#       4 name = 'ian'
#       5 job = 'developer'
#
# E:\Anaconda2\lib\site-packages\MySQLdb\__init__.pyc in Connect(*args, **kwargs)
#      79     """Factory function for connections.Connection."""
#      80     from MySQLdb.connections import Connection
# ---> 81     return Connection(*args, **kwargs)
#      82
#      83 connect = Connection = Connect
#
# E:\Anaconda2\lib\site-packages\MySQLdb\connections.pyc in __init__(self, *args, **kwargs)
#     191         autocommit = kwargs2.pop('autocommit', False)
#     192
# --> 193         super(Connection, self).__init__(*args, **kwargs2)
#     194         self.cursorclass = cursorclass
#     195         self.encoders = dict([ (k, v) for k, v in conv.items()
#
# OperationalError: (1045, "Access denied for user 'ian'@'localhost' (using password: YES)")

# %%
person_dict = {'name': 'david', 'job': 'ceo', 'hobby': 'reading'}

# %%
# Remember some methods of Dictionary

# %%
person_dict.items
# Out:
# <function items>

# %%
person_dict.items() # list of tuple, (key, value)
# Out:
# [('hobby', 'reading'), ('job', 'ceo'), ('name', 'david')]

# %%
person_dict.items()[0] # list of tuple, (key, value)
# Out:
# ('hobby', 'reading')

# %%
print person_dict.items()[0][0] # list of tuple, (key, value)
print person_dict.items()[0][1] # list of tuple, (key, value)
# Out:
# hobby
# reading

# %%
# Other methods of Dictionary

# %%
person_dict.keys()
# Out:
# ['hobby', 'job', 'name']

# %%
# create a string from a list of strings
# Out traget -> name, job, hobby
''.join(person_dict.keys())
# Out:
# 'hobbyjobname'

# %%
# create a string from a list of strings
# Out traget -> name, job, hobby
columns = ','.join(person_dict.keys())
print columns
# Out:
# hobby,job,name

# %%
person_dict.values()
# Out:
# ['reading', 'ceo', 'david']

# %%
db = MySQLdb.connect("localhost", "ian", "password", "testdb")
cursor = db.cursor()

name = person_dict.values()[2]
job = person_dict.values()[1]
hobby = person_dict.values()[0]

"""INSERT INTO contacts ( hobby,job,name ) VALUES ("running", "engineer", "david")"""
sql = """INSERT INTO contacts ( {} ) VALUES ("{}", "{}", "{}")""".format(columns, hobby, job, name)
cursor.execute(sql)
db.commit()

db.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-47-da10c0ab5e73> in <module>()
# ----> 1 db = MySQLdb.connect("localhost", "ian", "password", "testdb")
#       2 cursor = db.cursor()
#       3
#       4 name = person_dict.values()[2]
#       5 job = person_dict.values()[1]
#
# E:\Anaconda2\lib\site-packages\MySQLdb\__init__.pyc in Connect(*args, **kwargs)
#      79     """Factory function for connections.Connection."""
#      80     from MySQLdb.connections import Connection
# ---> 81     return Connection(*args, **kwargs)
#      82
#      83 connect = Connection = Connect
#
# E:\Anaconda2\lib\site-packages\MySQLdb\connections.pyc in __init__(self, *args, **kwargs)
#     191         autocommit = kwargs2.pop('autocommit', False)
#     192
# --> 193         super(Connection, self).__init__(*args, **kwargs2)
#     194         self.cursorclass = cursorclass
#     195         self.encoders = dict([ (k, v) for k, v in conv.items()
#
# OperationalError: (1045, "Access denied for user 'ian'@'localhost' (using password: YES)")

# %%
people_list = [{'name': 'david', 'job': 'ceo', 'hobby': 'reading'},
              {'name': 'ian', 'job': 'coo', 'hobby': 'surfing'},
              {'name': 'brian', 'job': 'cto', 'hobby': 'running'}]

# %%
people_list
# Out:
# [{'hobby': 'reading', 'job': 'ceo', 'name': 'david'},
#  {'hobby': 'surfing', 'job': 'coo', 'name': 'ian'},
#  {'hobby': 'running', 'job': 'cto', 'name': 'brian'}]

# %%
people_list[0] # dict
# Out:
# {'hobby': 'reading', 'job': 'ceo', 'name': 'david'}

# %%
people_list[0].keys()
# Out:
# ['hobby', 'job', 'name']

# %%
columns = ','.join(people_list[0].keys())
print columns
# Out:
# hobby,job,name

# %%
# GOAL -> [('cycling', 'engineer', 'ian'), ('reading', 'cto', 'brian')]
values_to_insert = []
for person in people_list:
    print tuple(person.values())
    values_to_insert.append(tuple(person.values()))
# Out:
# ('reading', 'ceo', 'david')
# ('surfing', 'coo', 'ian')
# ('running', 'cto', 'brian')

# %%
print values_to_insert
# Out:
# [('reading', 'ceo', 'david'), ('surfing', 'coo', 'ian'), ('running', 'cto', 'brian')]

# %%
values_to_insert = [tuple(x.values()) for x in people_list]

# %%
values_to_insert
# Out:
# [('reading', 'ceo', 'david'),
#  ('surfing', 'coo', 'ian'),
#  ('running', 'cto', 'brian')]

# %%
# What do we have now?
# columns
# values to insert

# %%
flatten = [y for x in values_to_insert for y in x]  
flatten
# Out:
# ['reading', 'ceo', 'david', 'surfing', 'coo', 'ian', 'running', 'cto', 'brian']

# %%
flatten = []
for mytuple in values_to_insert:
    for val in mytuple:
        flatten.append(val)
print flatten
# Out:
# ['reading', 'ceo', 'david', 'surfing', 'coo', 'ian', 'running', 'cto', 'brian']

# %%
mystr = "{}, {}, {},{}, {}, {},{}, {}, {}".format(*flatten)

# %%
print mystr
# Out:
# reading, ceo, david,surfing, coo, ian,running, cto, brian

# %%
db = MySQLdb.connect("localhost", "ian", "password", "testdb")
cursor = db.cursor()

name = person_dict.values()[2]
job = person_dict.values()[1]
hobby = person_dict.values()[0]

"""INSERT INTO contacts ( hobby,job,name ) VALUES ("running", "engineer", "david"), ("running", "engineer", "david"), ("running", "engineer", "david")"""
sql = """INSERT INTO contacts ( {} ) VALUES ("{}", "{}", "{}"), ("{}", "{}", "{}"), ("{}", "{}", "{}")""".format(columns, *flatten)
cursor.execute(sql)
db.commit()

db.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-62-444759c1c15b> in <module>()
# ----> 1 db = MySQLdb.connect("localhost", "ian", "password", "testdb")
#       2 cursor = db.cursor()
#       3
#       4 name = person_dict.values()[2]
#       5 job = person_dict.values()[1]
#
# E:\Anaconda2\lib\site-packages\MySQLdb\__init__.pyc in Connect(*args, **kwargs)
#      79     """Factory function for connections.Connection."""
#      80     from MySQLdb.connections import Connection
# ---> 81     return Connection(*args, **kwargs)
#      82
#      83 connect = Connection = Connect
#
# E:\Anaconda2\lib\site-packages\MySQLdb\connections.pyc in __init__(self, *args, **kwargs)
#     191         autocommit = kwargs2.pop('autocommit', False)
#     192
# --> 193         super(Connection, self).__init__(*args, **kwargs2)
#     194         self.cursorclass = cursorclass
#     195         self.encoders = dict([ (k, v) for k, v in conv.items()
#
# OperationalError: (1045, "Access denied for user 'ian'@'localhost' (using password: YES)")

# %%
# casting
mynum = 1
mystr = str(mynum)

# %%
type(mynum)
# Out:
# int

# %%
type(mystr)
# Out:
# str

# %%
# MySQLdb writer for variable columns

# %%
people_list = [{'name': 'david', 'job': 'ceo', 'hobby': 'reading'},
               {'name': 'ian', 'job': 'coo', 'hobby': 'surfing'},
               {'name': 'michael', 'job': 'engineer', 'hobby': 'cycling'},
               {'name': 'john', 'job': 'operations', 'hobby': 'skiing'},
               {'name': 'amy', 'job': 'designer', 'hobby': 'swimming'},
               {'name': 'brian', 'job': 'cto', 'hobby': 'running'}]

# %%
values_to_insert = [tuple(x.values()) for x in people_list]
values_to_insert
# Out:
# [('reading', 'ceo', 'david'),
#  ('surfing', 'coo', 'ian'),
#  ('cycling', 'engineer', 'michael'),
#  ('skiing', 'operations', 'john'),
#  ('swimming', 'designer', 'amy'),
#  ('running', 'cto', 'brian')]

# %%
flatten = [y for x in values_to_insert for y in x]  
flatten
# Out:
# ['reading',
#  'ceo',
#  'david',
#  'surfing',
#  'coo',
#  'ian',
#  'cycling',
#  'engineer',
#  'michael',
#  'skiing',
#  'operations',
#  'john',
#  'swimming',
#  'designer',
#  'amy',
#  'running',
#  'cto',
#  'brian']

# %%
columns = ','.join(people_list[0].keys())
columns
# Out:
# 'hobby,job,name'

# %%
def flush_to_db(data_list, table):    
    db = MySQLdb.connect("localhost", "ian", "password", "testdb", charset="utf-8")
    cursor = db.cursor()
    values_to_insert = [tuple(x.values()) for x in data_list]
    flatten = [y for x in values_to_insert for y in x]  
    columns = ','.join(data_list[0].keys())
    sql = """INSERT INTO {} ( {} ) VALUES""".format(table, columns) + ",".join("(%s,%s,%s)" for x in values_to_insert)
    print sql
    cursor.execute(sql, flatten)
    db.commit()

    db.close()

# %%
def list_crawler(url):
    """ This is a function that crawls the list page of appledaily news
        Args:
             url: The url of news list page
        Return:
             article_url_list: list of article urls
    """
    article_url_list = []
    res = r.get(url)
    soup = BeautifulSoup(res.text, 'lxml')
    news_list = soup.find_all('li', class_='rtddt')
    for news in news_list:
        print news.font.text
        # news.a['href'] does not include host http://www.appledaily.com.tw
        print "http://www.appledaily.com.tw" + news.a['href']
        article_url_list.append("http://www.appledaily.com.tw" + news.a['href'])
    return article_url_list

# %%
def parse_article(url):
    """This function extracts the title and content of the news article
       Args:
            url: url of the article
       Return:
            art_dict: dictionary of artilce title and content
            
            art_dict = {
                'title': "I am a title",
                'content': "This is the content of the news artile",
                'pub_date': "2016年08月26日09:15",
                'category': "sports"
            }
    
    """
    art_dict = {}
    res = r.get(url)
    soup = BeautifulSoup(res.text, 'lxml')
    art_dict['title'] = soup.find(id='h1').text
    art_dict['content'] = soup.find(id='summary').text
    art_dict['pub_date'] = datetime.strptime(soup.find('time').text.encode('utf-8'), u'%Y年%m月%d日%H:%M'.encode('utf-8'))
#art_dict['pub_date'] = soup.find('time').text
#     print url
#     print url.split('/')
#     print url.split('/')[5]
    art_dict['category'] = url.split('/')[5]
    return art_dict

# %%
# #encoding=utf-8
# import sys
# reload(sys)
# sys.setdefaultencoding('utf-8')
# let's crawl 10 pages of Appledaily
URL = "http://www.appledaily.com.tw/realtimenews/section/new/"
final_list = []
for page in range(1,6):
    # page is type int
    print "Crawling page {}".format(page)
    current_url = URL + str(page)
    print "Current url is {}".format(current_url)
    article_url_list = list_crawler(current_url) # We get the list of article_urls
    db_cnt = 0
    for article_url in article_url_list:
        try:
            final_list.append(parse_article(article_url))                
        except Exception as e:
            print e
    #flush_to_db(final_list, 'appledaily')
    #final_list = []
print final_list
# Out:
# Crawling page 1
# Current url is http://www.appledaily.com.tw/realtimenews/section/new/1
# ​上床送錢換非法入境　美國移民官飽私囊(0)
# http://www.appledaily.com.tw/realtimenews/article/international/20160910/946134/​上床送錢換非法入境　美國移民官飽私囊
# 【公庫】為何高雄迫遷居民與民主及台獨可以...(0)
# http://www.appledaily.com.tw/realtimenews/article/forum/20160910/946161/【公庫】為何高雄迫遷居民與民主及台獨可以扯在一起談？
# 佛心老闆宣布今天放假免補班　結果被抓包....(75675)
# http://www.appledaily.com.tw/realtimenews/article/life/20160910/946020/佛心老闆宣布今天放假免補班　結果被抓包...
# 女外勞自拍性侵過程求救　崩潰割腕送醫(0)
# http://www.appledaily.com.tw/realtimenews/article/local/20160910/946143/女外勞自拍性侵過程求救　崩潰割腕送醫
# 【央廣RTI】奧運檢討 教長：將觀摩英國...(0)
# http://www.appledaily.com.tw/realtimenews/article/sports/20160910/946157/【央廣RTI】奧運檢討教長：將觀摩英國選訓模式
# 【驚悚41J】女做愛高喊前夫名　遭男友開...(41576)
# http://www.appledaily.com.tw/realtimenews/article/international/20160910/945988/【驚悚41J】女做愛高喊前夫名　遭男友開膛破肚慘死
# 福原愛宣導交安遊行　民眾祝賀結婚(113)
# http://www.appledaily.com.tw/realtimenews/article/sports/20160910/946153/福原愛宣導交安遊行　民眾祝賀結婚
# 食物落地5秒還能吃？　研究：跟時間長短無...(1095)
# http://www.appledaily.com.tw/realtimenews/article/international/20160910/946144/食物落地5秒還能吃？　研究：跟時間長短無關
# 男生衣服為何比女生貴？　原來是這個原因(2318)
# http://www.appledaily.com.tw/realtimenews/article/life/20160910/946145/男生衣服為何比女生貴？　原來是這個原因
# 無良仲介放任狼雇主　性侵影片流回台灣(4477)
# http://www.appledaily.com.tw/realtimenews/article/local/20160910/946133/無良仲介放任狼雇主　性侵影片流回台灣
# 奇！裁判喊投手犯規　打者照敲全壘打(21309)
# http://www.appledaily.com.tw/realtimenews/article/sports/20160910/945984/奇！裁判喊投手犯規　打者照敲全壘打
# REDValentino的夢幻詩意　交給...(141)
# http://www.appledaily.com.tw/realtimenews/article/fashion/20160910/946112/REDValentino的夢幻詩意　交給英倫才女唱
# 滅火器挑戰20公里路跑　主唱尬完送去冰敷(389)
# http://www.appledaily.com.tw/realtimenews/article/entertainment/20160910/946113/滅火器挑戰20公里路跑　主唱尬完送去冰敷
# 【壹週刊】運動要假掰！Eason、蕾哈娜...(2381)
# http://www.appledaily.com.tw/realtimenews/article/nextmag/20160910/945524/【壹週刊】運動要假掰！Eason、蕾哈娜這麼說！
# 對流旺盛　北北基15縣市發布大雨特報(1434)
# http://www.appledaily.com.tw/realtimenews/article/life/20160910/946142/對流旺盛　北北基15縣市發布大雨特報
# 林全幫花蓮老榮民慶生　稱抱怨就是進步的動...(316)
# http://www.appledaily.com.tw/realtimenews/article/politics/20160910/946110/林全幫花蓮老榮民慶生　稱抱怨就是進步的動力
# 8年級生談判亮槍　見快打部隊嚇得先丟槍(2515)
# http://www.appledaily.com.tw/realtimenews/article/local/20160910/946131/8年級生談判亮槍　見快打部隊嚇得先丟槍
# ​金正恩為何打臉習近平？(1776)
# http://www.appledaily.com.tw/realtimenews/article/forum/20160910/946136/​金正恩為何打臉習近平？
# ​布拉球鞋尺寸22號　台灣有錢也買不到 ...(1430)
# http://www.appledaily.com.tw/realtimenews/article/sports/20160910/
e01\u5167\u8332\uff08Gilberto Aguilar-Martinez\uff09\uff0c\u88ab\u63a7\u5354\u52a9\u5077\u6e21\u5916\u7c4d\u4eba\u58eb\u3002\u4ed6\u66fe\u7d93\u5169\u5ea6\u88ab\u5224\u5211\uff0c\u4ee5\u975e\u6cd5\u79fb\u6c11\u8eab\u5206\u906d\u9063\u8fd4\u3002\u7531\u65bc3\u4eba\u6709\u9003\u8dd1\u4e4b\u5acc\uff0c\u6aa2\u5bdf\u5b98\u52d2\u4ee4\u7f88\u62bc3\u4eba\uff0c3\u4eba\u4e5f\u5c07\u5728\u4e0b\u5468\u4e09\uff0814\u65e5\uff09\u51fa\u5e2d\u62d8\u7559\u807d\u8b49\u6703\uff0c\u4e26\u9810\u8a08\u572822\u65e5\u51fa\u5ead\u3002\uff08\u8607\u7acb\uff0f\u7d9c\u5408\u5916\u96fb\u5831\u5c0e\uff09', 'category': u'international', 'pub_date': datetime.datetime(2016, 9, 10, 14, 24), 'title': u'\u200b\u4e0a\u5e8a\u9001\u9322\u63db\u975e\u6cd5\u5165\u5883\u3000\u7f8e\u570b\u79fb\u6c11\u5b98\u98fd\u79c1\u56ca'}, {'content': u'\u672c\u5167\u5bb9\u7531\u516c\u5eab\u63d0\u4f9b', 'category': u'forum', 'pub_date': datetime.datetime(2016, 9, 10, 14, 24), 'title': u'\u3010\u516c\u5eab\u3011\u70ba\u4f55\u9ad8\u96c4\u8feb\u9077\u5c45\u6c11\u8207\u6c11\u4e3b\u53ca\u53f0\u7368\u53ef\u4ee5\u626f\u5728\u4e00\u8d77\u8ac7\uff1f'}, {'content': u'\uff08\u66f4\u65b0\uff1a\u65b0\u589e\u5f71\u7247\uff09\u56e0\u61c9\u4e2d\u79cb4\u5929\u9023\u7e8c\u5047\u671f\uff0c\u4eca\u5929\u6709\u4e0d\u5c11\u54e1\u5de5\u548c\u5b78\u751f\u90fd\u88dc\u73ed\u3001\u88dc\u8ab2\uff0c\u4f46\u6709\u9593\u516c\u53f8\u537b\u9738\u6c23\u5ba3\u5e03\u653e\u5047\uff0c\u8b93\u54e1\u5de5\u597d\u597d\u4f11\u606f\uff0c\u4f46\u9019\u500b\u516c\u544a\u53cd\u906d\u9178\u7206\u4e86\uff01\u4e00\u540d\u7db2\u53cb\u5728\u81c9\u66f8\u300c\u7206\u6599\u516c\u793e\u300dPO\u6587\u300c\u6211\u89ba\u5f97\u6211\u5011\u8001\u95c6\u6709\u53cd\u793e\u6703\u4eba\u683c\uff0c\u4e0b\u73ed\u524d\u53c8\u6c7a\u5b9a\u660e\u5929\u5047\u7167\u653e\uff0c\u723d\u8cfa\u4e00\u5929\u5047\u3002\u300d\u4e26\u9644\u4e0a\u516c\u53f8\u7684\u516c\u544a\uff0c\u4e0a\u982d\u5beb\u8457\u300c\u8001\u95c6\u7531\u65bc\u4e0d\u660e\u767d\u5047\u65e5\u88dc\u73ed\u610f\u7fa9\u5 ...

# %%
final_list[0]['pub_date']
# Out:
# datetime.datetime(2016, 9, 10, 14, 24)

# %%
sql = """CREATE TABLE APPLEDAILY (
         TITLE VARCHAR(255) NOT NULL,
         CONTENT  TEXT,
         PUB_DATE DATETIME,
         CATEGORY VARCHAR(255))"""
db = MySQLdb.connect("localhost", "ian", "password", "testdb")
cursor = db.cursor()

print sql
cursor.execute(sql)
db.commit()

db.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-76-570615402370> in <module>()
#       4          PUB_DATE DATETIME,
#       5          CATEGORY VARCHAR(255))"""
# ----> 6 db = MySQLdb.connect("localhost", "ian", "password", "testdb")
#       7 cursor = db.cursor()
#       8
#
# E:\Anaconda2\lib\site-packages\MySQLdb\__init__.pyc in Connect(*args, **kwargs)
#      79     """Factory function for connections.Connection."""
#      80     from MySQLdb.connections import Connection
# ---> 81     return Connection(*args, **kwargs)
#      82
#      83 connect = Connection = Connect
#
# E:\Anaconda2\lib\site-packages\MySQLdb\connections.pyc in __init__(self, *args, **kwargs)
#     191         autocommit = kwargs2.pop('autocommit', False)
#     192
# --> 193         super(Connection, self).__init__(*args, **kwargs2)
#     194         self.cursorclass = cursorclass
#     195         self.encoders = dict([ (k, v) for k, v in conv.items()
#
# OperationalError: (1045, "Access denied for user 'ian'@'localhost' (using password: YES)")

# %% [markdown]
# # SQLAlchemy
# # ORM (Object Relational Mapping)

# %%
import sqlalchemy
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()

# %%
# connection string => username:password@host/database
engine = sqlalchemy.create_engine('mysql+mysqldb://ian:password@localhost/testdb?charset=utf8')

# %%
from sqlalchemy import Column, String, DateTime, Text, Integer
class AppleDaily(Base):
    __tablename__ = 'appledaily'
    
    id       = Column(Integer, primary_key=True)
    title    = Column(String(255))
    content  = Column(Text)
    pub_date = Column(DateTime)
    category = Column(String(255))

# %%
Base.metadata.create_all(engine)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-80-45cf70d5fd4c> in <module>()
# ----> 1 Base.metadata.create_all(engine)
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\sql\schema.pyc in create_all(self, bind, tables, checkfirst)
#    3693                           self,
#    3694                           checkfirst=checkfirst,
# -> 3695                           tables=tables)
#    3696
#    3697     def drop_all(self, bind=None, tables=None, checkfirst=True):
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\engine\base.pyc in _run_visitor(self, visitorcallable, element, connection, **kwargs)
#    1853     def _run_visitor(self, visitorcallable, element,
#    1854                      connection=None, **kwargs):
# -> 1855         with self._optional_conn_ctx_manager(connection) as conn:
#    1856             conn._run_visitor(visitorcallable, element, **kwargs)
#    1857
#
# E:\Anaconda2\lib\contextlib.pyc in __enter__(self)
#      15     def __enter__(self):
#      16         try:
# ---> 17             return self.gen.next()
#      18         except StopIteration:
#      19             raise RuntimeError("generator didn't yield")
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\engine\base.pyc in _optional_conn_ctx_manager(self, connection)
#    1846     def _optional_conn_ctx_manager(self, connection=None):
#    1847         if connection is None:
# -> 1848             with self.contextual_connect() as conn:
#    1849                 yield conn
#    1850         else:
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\engine\base.pyc in contextual_connect(self, close_with_result, **kwargs)
#    2037         return self._connection_cls(
#    2038             self,
# -> 2039             self._wrap_pool_connect(self.pool.connect, None),
#    2040             close_with_result=close_with_result,
#    2041             **kwargs)
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\engine\base.pyc in _wrap_pool_connect(self, fn, connection)
#    2076             if connection is None:
#    2077                 Connection._handle_dbapi_exception_noconnection(
# -> 2078                     e, dialect, self)
#    2079             else:
#    2080                 util.reraise(*sys.exc_info())
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\engine\base.pyc in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1403             util.raise_from_cause(
#    1404                 sqlalchemy_exception,
# -> 1405                 exc_info
#    1406             )
#    1407         else:
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\util\compat.pyc in raise_from_cause(exception, exc_info)
#     200     exc_type, exc_value, exc_tb = exc_info
#     201     cause = exc_value if exc_value is not exception else None
# --> 202     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     203
#     204 if py3k:
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\engine\base.pyc in _wrap_pool_connect(self, fn, connection)
#    2072         dialect = self.dialect
#    2073         try:
# -> 2074             return fn()
#    2075         except dialect.dbapi.Error as e:
#    2076             if connection is None:
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\pool.pyc in connect(self)
#     374         """
#     375         if not self._use_threadlocal:
# --> 376             return _ConnectionFairy._checkout(self)
#     377
#     378         try:
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\pool.pyc in _checkout(cls, pool, threadconns, fairy)
#     711     def _checkout(cls, pool, threadconns=None, fairy=None):
#     712         if not fairy:
# --> 713             fairy = _ConnectionRecord.checkout(pool)
#     714
#     715             fairy._pool = pool
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\pool.pyc in checkout(cls, pool)
#     478     @classmethod
#     479     def checkout(cls, pool):
# --> 480         rec = pool._do_get()
#     481         try:
#     482             dbapi_connection = rec.get_connection()
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\pool.pyc in _do_get(self)
#    1058                 except:
#    1059                     with util.safe_reraise():
# -> 1060                         self._dec_overflow()
#    1061             else:
#    1062                 return self._do_get()
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\util\langhelpers.pyc in __exit__(self, type_, value, traceback)
#      58             exc_type, exc_value, exc_tb = self._exc_info
#      59             self._exc_info = None   # remove potential circular references
# ---> 60             compat.reraise(exc_type, exc_value, exc_tb)
#      61         else:
#      62             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\pool.pyc in _do_get(self)
#    1055             if self._inc_overflow():
#    1056                 try:
# -> 1057                     return self._create_connection()
#    1058                 except:
#    1059                     with util.safe_reraise():
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\pool.pyc in _create_connection(self)
#     321         """Called by subclasses to create a new ConnectionRecord."""
#     322
# --> 323         return _ConnectionRecord(self)
#     324
#     325     def _invalidate(self, connection, exception=None):
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\pool.pyc in __init__(self, pool)
#     447     def __init__(self, pool):
#     448         self.__pool = pool
# --> 449         self.connection = self.__connect()
#     450         self.finalize_callback = deque()
#     451
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\pool.pyc in __connect(self)
#     605         try:
#     606             self.starttime = time.time()
# --> 607             connection = self.__pool._invoke_creator(self)
#     608             self.__pool.logger.debug("Created new connection %r", connection)
#     609             return connection
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\engine\strategies.pyc in connect(connection_record)
#      95                         if connection is not None:
#      96                             return connection
# ---> 97                 return dialect.connect(*cargs, **cparams)
#      98
#      99             creator = pop_kwarg('creator', connect)
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\engine\default.pyc in connect(self, *cargs, **cparams)
#     383
#     384     def connect(self, *cargs, **cparams):
# --> 385         return self.dbapi.connect(*cargs, **cparams)
#     386
#     387     def create_connect_args(self, url):
#
# E:\Anaconda2\lib\site-packages\MySQLdb\__init__.pyc in Connect(*args, **kwargs)
#      79     """Factory function for connections.Connection."""
#      80     from MySQLdb.connections import Connection
# ---> 81     return Connection(*args, **kwargs)
#      82
#      83 connect = Connection = Connect
#
# E:\Anaconda2\lib\site-packages\MySQLdb\connections.pyc in __init__(self, *args, **kwargs)
#     191         autocommit = kwargs2.pop('autocommit', False)
#     192
# --> 193         super(Connection, self).__init__(*args, **kwargs2)
#     194         self.cursorclass = cursorclass
#     195         self.encoders = dict([ (k, v) for k, v in conv.items()
#
# OperationalError: (_mysql_exceptions.OperationalError) (1045, "Access denied for user 'ian'@'localhost' (using password: YES)")

# %%
from sqlalchemy.orm import sessionmaker
Session = sessionmaker(bind=engine)
session = Session()

# %%
type(AppleDaily)
# Out:
# sqlalchemy.ext.declarative.api.DeclarativeMeta

# %%
print final_list[0]['content']
# Out:
# 美國海關與國境保護署（Customs and Border Protection）傳出有官員，以性愛和金錢作為交換條件，讓非法移民入境美國，周三被當局逮捕。50歲的官員寇達（Jose Luis Cota）在美國西南部的聖伊西卓入境關口（San Ysidro Port of Entry）任職，過去一年來，多次讓沒有證件的非法移民赫雷拉（Miriam Elizabeth Juarez-Herrera）和馬丁內茲（Gilberto Aguilar-Martinez），攜帶非法移民進入美國。聯邦調查局（FBI）特別官員畢爾恩鮑姆（Eric S. Birnbaum）表示，在2015年11月3日、11月16日與今年3月15日、9月7日，有高額款項進入寇達的帳戶，而每次有金額入帳，就會有非法移民夾帶入境。而31歲的非法移民赫雷拉被逮捕後，承認她用金錢和性交賄賂寇達。寇達自2001年8月加入海關與國境保護署，目前被停薪停職，被控妨礙公務、改造與捏造紀錄、公職人員行賄與收賄等罪名；赫雷拉則被控偷渡墨西哥非法外籍人士進入美國境內。當局同時也逮捕31歲的馬丁內茲（Gilberto Aguilar-Martinez），被控協助偷渡外籍人士。他曾經兩度被判刑，以非法移民身分遭遣返。由於3人有逃跑之嫌，檢察官勒令羈押3人，3人也將在下周三（14日）出席拘留聽證會，並預計在22日出庭。（蘇立／綜合外電報導）

# %%
session.bulk_insert_mappings(AppleDaily, final_list)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-84-23fad043054b> in <module>()
# ----> 1 session.bulk_insert_mappings(AppleDaily, final_list)
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\orm\session.pyc in bulk_insert_mappings(self, mapper, mappings, return_defaults)
#    2282         """
#    2283         self._bulk_save_mappings(
# -> 2284             mapper, mappings, False, False, return_defaults, False)
#    2285
#    2286     def bulk_update_mappings(self, mapper, mappings):
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\orm\session.pyc in _bulk_save_mappings(self, mapper, mappings, isupdate, isstates, return_defaults, update_changed_only)
#    2353         except:
#    2354             with util.safe_reraise():
# -> 2355                 transaction.rollback(_capture_exception=True)
#    2356         finally:
#    2357             self._flushing = False
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\util\langhelpers.pyc in __exit__(self, type_, value, traceback)
#      58             exc_type, exc_value, exc_tb = self._exc_info
#      59             self._exc_info = None   # remove potential circular references
# ---> 60             compat.reraise(exc_type, exc_value, exc_tb)
#      61         else:
#      62             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\orm\session.pyc in _bulk_save_mappings(self, mapper, mappings, isupdate, isstates, return_defaults, update_changed_only)
#    2348             else:
#    2349                 persistence._bulk_insert(
# -> 2350                     mapper, mappings, transaction, isstates, return_defaults)
#    2351             transaction.commit()
#    2352
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\orm\persistence.pyc in _bulk_insert(mapper, mappings, session_transaction, isstates, return_defaults)
#      45         mappings = list(mappings)
#      46
# ---> 47     connection = session_transaction.connection(base_mapper)
#      48     for table, super_mapper in base_mapper._sorted_tables.items():
#      49         if not mapper.isa(super_mapper):
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\orm\session.pyc in connection(self, bindkey, execution_options, **kwargs)
#     230         self._assert_active()
#     231         bind = self.session.get_bind(bindkey, **kwargs)
# --> 232         return self._connection_for_bind(bind, execution_options)
#     233
#     234     def _begin(self, nested=False):
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\orm\session.pyc in _connection_for_bind(self, bind, execution_options)
#     321
#     322         if self._parent:
# --> 323             conn = self._parent._connection_for_bind(bind, execution_options)
#     324             if not self.nested:
#     325                 return conn
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\orm\session.pyc in _connection_for_bind(self, bind, execution_options)
#     332                         "given Connection's Engine")
#     333             else:
# --> 334                 conn = bind.contextual_connect()
#     335
#     336         if execution_options:
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\engine\base.pyc in contextual_connect(self, close_with_result, **kwargs)
#    2037         return self._connection_cls(
#    2038             self,
# -> 2039             self._wrap_pool_connect(self.pool.connect, None),
#    2040             close_with_result=close_with_result,
#    2041             **kwargs)
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\engine\base.pyc in _wrap_pool_connect(self, fn, connection)
#    2076             if connection is None:
#    2077                 Connection._handle_dbapi_exception_noconnection(
# -> 2078                     e, dialect, self)
#    2079             else:
#    2080                 util.reraise(*sys.exc_info())
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\engine\base.pyc in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1403             util.raise_from_cause(
#    1404                 sqlalchemy_exception,
# -> 1405                 exc_info
#    1406             )
#    1407         else:
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\util\compat.pyc in raise_from_cause(exception, exc_info)
#     200     exc_type, exc_value, exc_tb = exc_info
#     201     cause = exc_value if exc_value is not exception else None
# --> 202     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     203
#     204 if py3k:
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\engine\base.pyc in _wrap_pool_connect(self, fn, connection)
#    2072         dialect = self.dialect
#    2073         try:
# -> 2074             return fn()
#    2075         except dialect.dbapi.Error as e:
#    2076             if connection is None:
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\pool.pyc in connect(self)
#     374         """
#     375         if not self._use_threadlocal:
# --> 376             return _ConnectionFairy._checkout(self)
#     377
#     378         try:
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\pool.pyc in _checkout(cls, pool, threadconns, fairy)
#     711     def _checkout(cls, pool, threadconns=None, fairy=None):
#     712         if not fairy:
# --> 713             fairy = _ConnectionRecord.checkout(pool)
#     714
#     715             fairy._pool = pool
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\pool.pyc in checkout(cls, pool)
#     478     @classmethod
#     479     def checkout(cls, pool):
# --> 480         rec = pool._do_get()
#     481         try:
#     482             dbapi_connection = rec.get_connection()
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\pool.pyc in _do_get(self)
#    1058                 except:
#    1059                     with util.safe_reraise():
# -> 1060                         self._dec_overflow()
#    1061             else:
#    1062                 return self._do_get()
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\util\langhelpers.pyc in __exit__(self, type_, value, traceback)
#      58             exc_type, exc_value, exc_tb = self._exc_info
#      59             self._exc_info = None   # remove potential circular references
# ---> 60             compat.reraise(exc_type, exc_value, exc_tb)
#      61         else:
#      62             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\pool.pyc in _do_get(self)
#    1055             if self._inc_overflow():
#    1056                 try:
# -> 1057                     return self._create_connection()
#    1058                 except:
#    1059                     with util.safe_reraise():
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\pool.pyc in _create_connection(self)
#     321         """Called by subclasses to create a new ConnectionRecord."""
#     322
# --> 323         return _ConnectionRecord(self)
#     324
#     325     def _invalidate(self, connection, exception=None):
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\pool.pyc in __init__(self, pool)
#     447     def __init__(self, pool):
#     448         self.__pool = pool
# --> 449         self.connection = self.__connect()
#     450         self.finalize_callback = deque()
#     451
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\pool.pyc in __connect(self)
#     605         try:
#     606             self.starttime = time.time()
# --> 607             connection = self.__pool._invoke_creator(self)
#     608             self.__pool.logger.debug("Created new connection %r", connection)
#     609             return connection
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\engine\strategies.pyc in connect(connection_record)
#      95                         if connection is not None:
#      96                             return connection
# ---> 97                 return dialect.connect(*cargs, **cparams)
#      98
#      99             creator = pop_kwarg('creator', connect)
#
# E:\Anaconda2\lib\site-packages\sqlalchemy\engine\default.pyc in connect(self, *cargs, **cparams)
#     383
#     384     def connect(self, *cargs, **cparams):
# --> 385         return self.dbapi.connect(*cargs, **cparams)
#     386
#     387     def create_connect_args(self, url):
#
# E:\Anaconda2\lib\site-packages\MySQLdb\__init__.pyc in Connect(*args, **kwargs)
#      79     """Factory function for connections.Connection."""
#      80     from MySQLdb.connections import Connection
# ---> 81     return Connection(*args, **kwargs)
#      82
#      83 connect = Connection = Connect
#
# E:\Anaconda2\lib\site-packages\MySQLdb\connections.pyc in __init__(self, *args, **kwargs)
#     191         autocommit = kwargs2.pop('autocommit', False)
#     192
# --> 193         super(Connection, self).__init__(*args, **kwargs2)
#     194         self.cursorclass = cursorclass
#     195         self.encoders = dict([ (k, v) for k, v in conv.items()
#
# OperationalError: (_mysql_exceptions.OperationalError) (1045, "Access denied for user 'ian'@'localhost' (using password: YES)")

# %%
session.commit()

# %%
# Query

# %%
dir(session.query(AppleDaily).order_by(AppleDaily.pub_date))

# %%
for row in session.query(AppleDaily).order_by(AppleDaily.pub_date):
    print row.title

# %%
for row in session.query(AppleDaily).filter(AppleDaily.id == '40'):
    print row.title

# %%
for row in session.query(AppleDaily).filter(AppleDaily.title.like("%ScooTube%")):
    print row.title
    print row.content

# %%
import pandas as pd

# %%
order = pd.read_table('http://bit.ly/chiporders') # Read tab seperated file

# %%
order

# %%
news = pd.DataFrame(final_list)

# %%
news

# %%
news.count()

# %%
news.shape

# %%
news.describe()

# %%
type(news)

# %%
news.query('category == "life"')

# %%
news.category

# %%
news.groupby('category').count()

# %%
news.groupby('category').count().sort_values('content', ascending=False)

# %%
news_stat = news.groupby('category').count().sort_values('content', ascending=False)

# %%
type(news_stat)

# %%
news_stat.index

# %%
news_stat.to_sql('news_stat', engine, if_exists='replace', index=False, index_label=news_stat.index)

# %% [markdown]
# # pd.read_sql

# %%
news

# %%
news.to_dict('records')

# %%
news['category_title'] = news.category.str.title()

# %%
news

# %%
news.drop('category', axis=1, inplace=True)

# %%
news

# %%
news.rename(columns={'category_title': 'category', 'content': 'body'}, inplace=True)

# %%
news

# %%
news['title_len'] = news.title.apply(len)

# %%
news

# %%
news.query('title_len > 25')

# %%
news[news.title_len > 25]

# %%
news[(news.title_len > 25) & (news.category == "Life")]

# %%
news[(news.title_len > 25) | (news.category == "Life")]
