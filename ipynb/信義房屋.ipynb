# %%
import requests as r
from bs4 import BeautifulSoup
import pandas as pd
import sqlalchemy
from sqlalchemy.ext.declarative import declarative_base

headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.116 Safari/537.36'}
url='http://buy.sinyi.com.tw/list/Taipei-city/104-zip/'

# %%
url='http://buy.sinyi.com.tw/list/Taipei-city/104-zip/'
url_list=[]
for i in range(1,47):
    url_list.append(url+str(i)+'.html')
url_list
# Out:
# ['http://buy.sinyi.com.tw/list/Taipei-city/104-zip/1.html',
#  'http://buy.sinyi.com.tw/list/Taipei-city/104-zip/2.html',
#  'http://buy.sinyi.com.tw/list/Taipei-city/104-zip/3.html',
#  'http://buy.sinyi.com.tw/list/Taipei-city/104-zip/4.html',
#  'http://buy.sinyi.com.tw/list/Taipei-city/104-zip/5.html',
#  'http://buy.sinyi.com.tw/list/Taipei-city/104-zip/6.html',
#  'http://buy.sinyi.com.tw/list/Taipei-city/104-zip/7.html',
#  'http://buy.sinyi.com.tw/list/Taipei-city/104-zip/8.html',
#  'http://buy.sinyi.com.tw/list/Taipei-city/104-zip/9.html',
#  'http://buy.sinyi.com.tw/list/Taipei-city/104-zip/10.html',
#  'http://buy.sinyi.com.tw/list/Taipei-city/104-zip/11.html',
#  'http://buy.sinyi.com.tw/list/Taipei-city/104-zip/12.html',
#  'http://buy.sinyi.com.tw/list/Taipei-city/104-zip/13.html',
#  'http://buy.sinyi.com.tw/list/Taipei-city/104-zip/14.html',
#  'http://buy.sinyi.com.tw/list/Taipei-city/104-zip/15.html',
#  'http://buy.sinyi.com.tw/list/Taipei-city/104-zip/16.html',
# ...

# %% [markdown]
# ## 內文爬蟲

# %%
final = pd.DataFrame(final_content)
engine = sqlalchemy.create_engine('mysql+mysqldb://root:5332bl4c@localhost/house?charset=utf8')

# %%
final.to_sql('house', engine, if_exists='replace', index=False, index_label=final)
# Out:
# E:\Anaconda2\lib\site-packages\sqlalchemy\engine\default.py:450: Warning: Incorrect string value: '\xA5x\xA5_\xBC\xD0...' for column 'VARIABLE_VALUE' at row 478
#   cursor.execute(statement, parameters)
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-9-23561c2447ed> in <module>()
# ----> 1 final.to_sql('house', engine, if_exists='replace', index=False, index_label=final)
#
# E:\Anaconda2\lib\site-packages\pandas\core\generic.pyc in to_sql(self, name, con, flavor, schema, if_exists, index, index_label, chunksize, dtype)
#    1163         sql.to_sql(self, name, con, flavor=flavor, schema=schema,
#    1164                    if_exists=if_exists, index=index, index_label=index_label,
# -> 1165                    chunksize=chunksize, dtype=dtype)
#    1166
#    1167     def to_pickle(self, path):
#
# ...

# %%
final_content=[]

for x in url_list:
    cookies = {'__uid':'wKgIZFfH+B4wWwnUA1c4Ag==', '_gat_UA-12807964-17':'1',' __uwait':'0',' _ga':'GA1.3.1056451280.1472722974', '_gat':'1',' _ga':'GA1.4.1056451280.1472722974'}
    res = r.get(x,headers=headers,cookies = cookies)
    soup = BeautifulSoup(res.text,'lxml')
    crawling_list = soup.select('.search_result_item')
    
    for parse_article in crawling_list:
        p_dict={}
        p_dict['title']= parse_article.select('.item_title')[0].text
        p_dict['address'] = parse_article.select('.detail_line1')[0].span.text
        p_dict['place'] = parse_article.select('.detail_line2')[0].span.text
        p_dict['price'] = parse_article.select('.detail_price')[0].span.text
        final_content.append(p_dict)
        print p_dict['title']
    final = pd.DataFrame(final_content)
    engine = sqlalchemy.create_engine('mysql+mysqldb://root:5332bl4c@localhost/house?charset=utf8')
    final.to_sql('house', engine, if_exists='replace', index=False, index_label=final)
# Out:
# 近捷運鉑麗豪邸
# 中山官邸鋼骨豪邸
# 中山官邸靜巷豪邸
# 中山北景觀住辦
# 羅馬高樓景觀三房
# 松江邊間採光宅
# 復北典雅三樓美寓
# 超值公寓
# 好便宜雙城大廈
# 龍江大戶四房二樓
# 捷運靜巷邊間美廈
# 近捷運高樓阿摩兔
# 林森七條精美公寓
# 松江南京捷運廈
# 忠泰明高雅精品
# 長虹敦煌靜巷一樓
# 明亮方正邊間純辦
# 松江精美辦公室
# 捷運明亮兩房華廈
# 長安賦四房露台戶
# 華山方正電梯２房
# 國家金融捷運商辦
# 龍江邊間三房美廈
# 亞都景觀高樓辦公
# 微風獨棟華廈車位
# 民權雙捷‧靜謐居
# 發發長春公園套房
# 國賓旁三角窗Ａ店
# 阿曼風尚１＋１
# 將捷真愛高樓美景
# 農安四房成交首選
# 至尊九仰大戶豪邸
# 大直福園溫馨好屋
# 台北松江高樓讚
# 雙橡園朝南美豪邸
# 民生東成家二房
# 南京雙捷公園豪邸
# 華山官邸林蔭後棟
# 松江面校園優美廈
# 松江低總價首選
# 力麒蕭邦大氣名宅
# 頂極南京ＶＩＰ
# 蘭亭河景樓中樓
# 方城市邊間美宅
# 親愛的幸福麗緻
# 時尚４米２美妍家
# 遠雄首府誠意出售
# 方城市方正二樓
# 藏玉經典邊間３房
# 松江電梯捷運２房
# 晴光電梯捷運美宅
# 大直香榭５房車位
# 捷運獨棟優質店辦
# 松江雙捷方正雅寓
# 華山設計商辦
# 復興南京黃金一樓
# 大直歌林３＋１
# 國泰吉祥美廈
# 基泰之星景觀高樓
# 華固綠海典藏鼎苑
# 松江明珠亮麗美套
# 麗池國賓邊間美宅
# 邊間電梯美三房
# 大直現代風格
# 震大日光邊間美邸
# 松江雅築高樓住辦
# 民生收租自住首選
# 長安一品附車位Ｂ
# 稀有一樓小品辦公
# 晴光捷運電梯２房
# 中山晴光電梯美宅
# 閱禾琚邊間溫馨宅
# 京硯明亮景觀豪邸
# 基泰之星精美雅築
# 昇陽精裝挑高美宅
# 捷運漢宮精品兩房
# 超搶手公寓三樓
# 中山國小住辦小品
# 高樓景觀羅浮宮
# 國泰捷運黃金三樓
# 雙捷長寧管理三房
# 美四房川普３車位
# 佳麗寶邊間小資宅
# 東騰後棟美景豪邸
# 微風禮蘭後棟林蔭
# Ｍ浩斯捷運美景宅
# 遠雄朝日．誠售
# 劍南站御學園美寓
# 新光桂冠管理美廈
# 新生北發財金店面
# 禾碩榮星正面公園
# 六本木美裝屋
# 時尚精品麗舍美築
# ...
