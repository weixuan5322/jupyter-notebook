# %%
import requests as r
from bs4 import BeautifulSoup
url = 'https://buy.yungching.com.tw/region/%E5%8F%B0%E5%8C%97%E5%B8%82-_c/'
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.116 Safari/537.36'}
res=r.get(url,headers = headers)
soup = BeautifulSoup(res.text,'lxml')

# %%
print soup.select('.item-info')[0].h3.text.split()[1]
print soup.select('.item-info-detail')[0].text.split('\n')[7]
# Out:
# 台北市大安區羅斯福路三段
# 主+陽 38.02坪

# %%
crawling_list = soup.find_all('li','m-list-item')#全頁面

# %%
crawling_list
# Out:
# [<li class="m-list-item">\n<a class="item-img ga_click_trace" ga_cat="buy_list" ga_event="buy_list_click" ga_label="buy_list_info_photo_main" href="/house/2227937" target="_blank" title="\u53f0\u5927\u6377\u904b\u7a00\u6709\u56db\u623f \u53f0\u5317\u5e02\u5927\u5b89\u5340\u7f85\u65af\u798f\u8def\u4e09\u6bb5"><img alt="\u53f0\u5927\u6377\u904b\u7a00\u6709\u56db\u623f \u53f0\u5317\u5e02\u5927\u5b89\u5340\u7f85\u65af\u798f\u8def\u4e09\u6bb5" onerror="this.src='/Content/img/non-photo.png';" src="//pic.hfcdn.com/res/DrawImage/ShowPic/240/180/YC03/2227937/X.jpg?t=-391386754"/></a>\n<div class="item-info">\n<a class="item-title ga_click_trace" ga_cat="buy_list" ga_event="buy_list_click" ga_label="buy_list_title" href="/house/2227937" target="_blank" title="\u53f0\u5927\u6377\u904b\u7a00\u6709\u56db\u623f \u53f0\u5317\u5e02\u5927\u5b89\u5340\u7f85\u65af\u798f\u8def\u4e09\u6bb5"><h3>\u53f0\u5927\u6377\u904b\u7a00\u6709\u56db\u623f\u3000\u53f0\u5317\u5e02\u5927\u5b89\u5340\u7f85\u65af\u798f\u8
# ...

# %%
import requests as r
from bs4 import BeautifulSoup
import pandas as pd
import sqlalchemy

url = 'https://buy.yungching.com.tw/region/%E5%8F%B0%E5%8C%97%E5%B8%82-_c/?pg='
url_list = []
for x in range(1,290):
    url_list.append(url+str(x))

final_content = []
for y in url_list:
    res=r.get(y,headers = headers)
    soup = BeautifulSoup(res.text,'lxml')
    crawling_list = soup.find_all('li',class_='m-list-item')

    for parse_article in crawling_list:
        p_dict={}
        p_dict['address'] = parse_article.select('.item-info')[0].h3.text.split()[1]
        p_dict['place'] = parse_article.select('.item-info-detail')[0].text.split('\n')[7]
        p_dict['price'] = parse_article.select('.price')[0].text
        final_content.append(p_dict)
        print p_dict['price']
        
    final = pd.DataFrame(final_content)    #pd,DataFrame(裡面為list)
    engine = sqlalchemy.create_engine('mysql+mysqldb://root:5332bl4c@localhost/Yongqing?charset=utf8')
    final.to_sql('testhr', engine, if_exists='replace', index=False, index_label=final)
# Out:
# 3,668 萬
# 9,900 萬
# 2,088 萬
# 750 萬
# 32,000 萬
# 1,480 萬
# 2,680 萬
# 10,415 萬
# 10,315 萬
